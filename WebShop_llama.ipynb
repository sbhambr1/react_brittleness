# %% [markdown]
# # Setup

# %% [markdown]
# Before running this script in a separate terminal :
# ```cmd
# source /webvenv/bin/activate
# cd /webshop
# ./run_dev.sh
# ```
# Copy the url should be `172.17.0.3:3000` (or something like this)
#
# **Remember : Do not close this server terminal : Advice : Run it on a separate tmux session**

# %%
import sys, os
import boto3
from botocore.exceptions import ClientError

os.environ["OPENAI_API_KEY"] = None
os.environ["AWS_ACCESS_KEY"] =None
os.environ["AWS_SECRET_ACCESS_KEY"] = None

# %%
from openai import OpenAI
import time 
import json 

LLM_MODEL = "meta.llama3-1-8b-instruct-v1:0"

class LLM : 
    def __init__(self, model, file_path) -> None:
        self.model = model
        if 'gpt' in self.model:
            self.client = OpenAI(
                api_key=os.environ["OPENAI_API_KEY"],
            )
        elif 'llama3-1' in self.model:
            self.client = boto3.client("bedrock-runtime", region_name="us-west-2")
            
        self.file_path = file_path
        if not os.path.exists(file_path):
            os.makedirs(os.path.dirname(file_path), exist_ok=True)
            
        with open(file_path, 'w') as json_file:
            json.dump([], json_file)
    

    def llm(self, prompt, stop=["\n"]):
        try : 
            res = self._llm(prompt, stop)
            return res
        except Exception as e:
            print(f"Error: {e}")
            print("Waiting 100 seconds and Retrying")
            time.sleep(100)
            res = self.llm(prompt, stop)
            return res
     
    def _llm(self, prompt, stop=["\n"]):
        message, answer = '', ''
        if LLM_MODEL in ["gpt-3.5-turbo", "gpt-4o-mini", "gpt-4o"]: 
            message = [{"role": "user", "content": prompt}]
            response = self.client.chat.completions.create(
                model= LLM_MODEL, 
                messages= message,
                temperature=0.0,
                max_tokens=100,
                top_p=1.0,
                frequency_penalty=0.0,
                presence_penalty=0.0,
                stop=stop,
            )
            answer = response.choices[0].message.content

        elif LLM_MODEL == "gpt-3.5-turbo-instruct":
            response = self.client.completions.create(
                model=LLM_MODEL,
                prompt=prompt,
                temperature=0,
                max_tokens=100,
                top_p=1,
                frequency_penalty=0.0,
                presence_penalty=0.0,
                stop=stop
                )
            answer = response.choices[0].text
            
        elif 'llama3' in self.model:
            prompt += "Only provide the one action at a time. Be concise, and do not provide any extra information. Always start with the action."
            formatted_prompt = f"""
            <|begin_of_text|>
            <|start_header_id|>user<|end_header_id|>
            {prompt}
            <|eot_id|>
            <|start_header_id|>assistant<|end_header_id|>
            """

            # Format the request payload using the model's native structure.
            native_request = {
                "prompt": formatted_prompt,
                "max_gen_len": 512,
                "temperature": 0,
            }
            
            request = json.dumps(native_request)
            try:
                # Invoke the model with the request.
                response = self.client.invoke_model(modelId=self.model, body=request)

            except (ClientError, Exception) as e:
                print(f"ERROR: Can't invoke '{self.model}'. Reason: {e}")
                exit(1)

            # Decode the response body.
            model_response = json.loads(response["body"].read())

            # Extract and print the response text.
            answer = model_response["generation"]
            if answer[0] == ' ':
                answer = answer[1:]
            response = answer

        self.save_response(message, response)
        return answer
    
    def save_response(self, message, response):
        if 'gpt' in self.model:
            data = {
                "message": message,
                "response": json.loads(response.to_json()),
            }
        elif 'llama3' in self.model:
            data = {
                "message": message,
                "response": response,
            }
        # append response to an existing json file
        file_path = self.file_path            

        with open(file_path, 'r') as json_file:
            existing_data = json.load(json_file)
        existing_data.append(data)
        with open(file_path, 'w') as json_file:
            json.dump(existing_data, json_file)

# %%
import requests
from bs4 import BeautifulSoup
from bs4.element import Comment

# WEBSHOP_URL = "http://3.83.245.205:3000"
# WEBSHOP_URL = "http://172.17.0.3:3000/"
WEBSHOP_URL = "http://127.0.0.1:3000"
ACTION_TO_TEMPLATE = {
    'Description': 'description_page.html',
    'Features': 'features_page.html',
    'Reviews': 'review_page.html',
    'Attributes': 'attributes_page.html',
}

def clean_str(p):
  return p.encode().decode("unicode-escape").encode("latin1").decode("utf-8")


def tag_visible(element):
    ignore = {'style', 'script', 'head', 'title', 'meta', '[document]'}
    return (
        element.parent.name not in ignore and not isinstance(element, Comment)
    )


def webshop_text(session, page_type, query_string='', page_num=1, asin='', options={}, subpage='', **kwargs):
    if page_type == 'init':
      url = (
          f'{WEBSHOP_URL}/{session}'
      )
    if page_type == 'search':
      url = (
          f'{WEBSHOP_URL}/search_results/{session}/'
          f'{query_string}/{page_num}'
      )
    elif page_type == 'item':
      url = (
          f'{WEBSHOP_URL}/item_page/{session}/'
          f'{asin}/{query_string}/{page_num}/{options}'
      )
    elif page_type == 'item_sub':
      url = (
          f'{WEBSHOP_URL}/item_sub_page/{session}/'
          f'{asin}/{query_string}/{page_num}/{subpage}/{options}'
      )
    elif page_type == 'end':
      url = (
          f'{WEBSHOP_URL}/done/{session}/'
          f'{asin}/{options}'
      )
    # print(url)
    html = requests.get(url).text
    html_obj = BeautifulSoup(html, 'html.parser')
    texts = html_obj.findAll(text=True)
    visible_texts = list(filter(tag_visible, texts))
    # visible_texts = [str(text).strip().strip('\\n') for text in visible_texts]
    # if page_type == 'end': import pdb; pdb.set_trace()
    if False:
        # For `simple` mode, return just [SEP] separators
        return ' [SEP] '.join(t.strip() for t in visible_texts if t != '\n')
    else:
        # Otherwise, return an observation with tags mapped to specific, unique separators
        observation = ''
        option_type = ''
        options = {}
        asins = []
        cnt = 0
        prod_cnt = 0
        just_prod = 0
        for t in visible_texts:
            if t == '\n': continue
            if t.replace('\n', '').replace('\\n', '').replace(' ', '') == '': continue
            # if t.startswith('Instruction:') and page_type != 'init': continue
            # print(t.parent.name, t)
            if t.parent.name == 'button':  # button
                processed_t = f'\n[{t}] '
            elif t.parent.name == 'label':  # options
                if f"'{t}'" in url:
                    processed_t = f'[[{t}]]'
                    # observation = f'You have clicked {t}.\n' + observation
                else:
                    processed_t = f'[{t}]'
                options[str(t)] = option_type
                # options[option_type] = options.get(option_type, []) + [str(t)]
            elif t.parent.get('class') == ["product-link"]: # product asins
                processed_t = f'\n[{t}] '
                if prod_cnt >= 3:
                  processed_t = ''
                prod_cnt += 1
                asins.append(str(t))
                just_prod = 0
            else: # regular, unclickable text
                processed_t =  '\n' + str(t) + ' '
                if cnt < 2 and page_type != 'init': processed_t = ''
                if just_prod <= 2 and prod_cnt >= 4: processed_t = ''
                option_type = str(t)
                cnt += 1
            just_prod += 1
            observation += processed_t
        info = {}
        if options:
          info['option_types'] = options
        if asins:
          info['asins'] = asins
        if 'Your score (min 0.0, max 1.0)' in visible_texts:
          idx = visible_texts.index('Your score (min 0.0, max 1.0)')
          info['reward'] = float(visible_texts[idx + 1])
          observation = 'Your score (min 0.0, max 1.0): ' + (visible_texts[idx + 1])
        return clean_str(observation), info

class webshopEnv:
  def __init__(self):
    self.sessions = {}
  
  def step(self, session, action):
    done = False
    observation_ = None
    if action == 'reset':
      self.sessions[session] = {'session': session, 'page_type': 'init'}
    elif action.startswith('think['):
      observation = 'OK.'
    elif action.startswith('search['):
      assert self.sessions[session]['page_type'] == 'init'
      query = action[7:-1]
      self.sessions[session] = {'session': session, 'page_type': 'search',
                                'query_string': query, 'page_num': 1}
    elif action.startswith('click['):
      button = action[6:-1]
      if button == 'Buy Now':
        assert self.sessions[session]['page_type'] == 'item'
        self.sessions[session]['page_type'] = 'end'
        done = True
      elif button == 'Back to Search':
        assert self.sessions[session]['page_type'] in ['search', 'item_sub', 'item']
        self.sessions[session] = {'session': session, 'page_type': 'init'}
      elif button == 'Next >':
        assert False # ad hoc page limitation
        assert self.sessions[session]['page_type'] == 'search'
        self.sessions[session]['page_num'] += 1
      elif button == '< Prev':
        assert self.sessions[session]['page_type'] in ['search', 'item_sub', 'item']
        if self.sessions[session]['page_type'] == 'search':
          assert False
          self.sessions[session]['page_num'] -= 1
        elif self.sessions[session]['page_type'] == 'item_sub':
          self.sessions[session]['page_type'] = 'item'
        elif self.sessions[session]['page_type'] == 'item':
          self.sessions[session]['page_type'] = 'search'
          self.sessions[session]['options'] = {}
      elif button in ACTION_TO_TEMPLATE:
        assert self.sessions[session]['page_type'] == 'item'
        self.sessions[session]['page_type'] = 'item_sub'
        self.sessions[session]['subpage'] = button
      else:
        if self.sessions[session]['page_type'] == 'search':
          assert button in self.sessions[session].get('asins', [])  # must be asins
          self.sessions[session]['page_type'] = 'item'
          self.sessions[session]['asin'] = button
        elif self.sessions[session]['page_type'] == 'item':
          assert 'option_types' in self.sessions[session]
          assert button in self.sessions[session]['option_types'], (button, self.sessions[session]['option_types'])  # must be options
          option_type = self.sessions[session]['option_types'][button]
          if not 'options' in self.sessions[session]:
            self.sessions[session]['options'] = {}
          self.sessions[session]['options'][option_type] = button
          observation_ = f'You have clicked {button}.'
    else:
      assert False
    observation, info = webshop_text(**self.sessions[session])
    if observation_:
      observation = observation_
    self.sessions[session].update(info)
    reward = info.get('reward', 0.0)
    return observation, reward, done
env = webshopEnv()

# %% [markdown]
# # ReAct

# %%
#REACT baseline trivial search & item, choose option
prompt1 = """Webshop 
Instruction:  
i would like a 3 ounce bottle of bright citrus deodorant for sensitive skin, and price lower than 50.00 dollars 
[Search]  

Action: search[3 ounce bright citrus deodorant sensitive skin]
Observation: 
[Back to Search] 
Page 1 (Total results: 50) 
[Next >] 
[B078GWRC1J] 
Bright Citrus Deodorant by Earth Mama | Natural and Safe for Sensitive Skin, Pregnancy and Breastfeeding, Contains Organic Calendula 3-Ounce 
$10.99 
[B078GTKVXY] 
Ginger Fresh Deodorant by Earth Mama | Natural and Safe for Sensitive Skin, Pregnancy and Breastfeeding, Contains Organic Calendula 3-Ounce 
$10.99 
[B08KBVJ4XN] 
Barrel and Oak - Aluminum-Free Deodorant, Deodorant for Men, Essential Oil-Based Scent, 24-Hour Odor Protection, Cedar & Patchouli Blend, Gentle on Sensitive Skin (Mountain Sage, 2.7 oz, 2-Pack) 
$15.95  

Action: think[B078GWRC1J and B078GTKVXY are bright citrus deodorant less then 50 dollars. I can check B078GWRC1J first.]
Observation: OK.

Action: click[B078GWRC1J]
Observation: 
[Back to Search] 
[< Prev] 
scent [assorted scents][bright citrus][calming lavender][ginger fresh][simply non-scents]
size [travel set (4-pack)][3 ounce (pack of 1)][3-ounce (2-pack)]
Bright Citrus Deodorant by Earth Mama | Natural and Safe for Sensitive Skin, Pregnancy and Breastfeeding, Contains Organic Calendula 3-Ounce 
Price: $10.99 
Rating: N.A. 
[Description] 
[Features] 
[Reviews] 
[Buy Now]  

Action: think[For 3 ounce bottle of bright citrus deodorant for sensitive skin, the item has options 'bright citrus' and '3 ounce (pack of 1)' and seems good to buy.]
Observation: OK.

Action: click[bright citrus]
Observation: You have clicked bright citrus. 

Action: click[3 ounce (pack of 1)]
Observation: You have clicked 3 ounce (pack of 1). 

Action: click[Buy Now]
"""

# %%
# ACT Only : trivial search & item, choose option
prompt1_actonly = """Webshop 
Instruction:  
i would like a 3 ounce bottle of bright citrus deodorant for sensitive skin, and price lower than 50.00 dollars 
[Search]  

Action: search[3 ounce bright citrus deodorant sensitive skin]
Observation: 
[Back to Search] 
Page 1 (Total results: 50) 
[Next >] 
[B078GWRC1J] 
Bright Citrus Deodorant by Earth Mama | Natural and Safe for Sensitive Skin, Pregnancy and Breastfeeding, Contains Organic Calendula 3-Ounce 
$10.99 
[B078GTKVXY] 
Ginger Fresh Deodorant by Earth Mama | Natural and Safe for Sensitive Skin, Pregnancy and Breastfeeding, Contains Organic Calendula 3-Ounce 
$10.99 
[B08KBVJ4XN] 
Barrel and Oak - Aluminum-Free Deodorant, Deodorant for Men, Essential Oil-Based Scent, 24-Hour Odor Protection, Cedar & Patchouli Blend, Gentle on Sensitive Skin (Mountain Sage, 2.7 oz, 2-Pack) 
$15.95  

Action: click[B078GWRC1J]
Observation: 
[Back to Search] 
[< Prev] 
scent [assorted scents][bright citrus][calming lavender][ginger fresh][simply non-scents]
size [travel set (4-pack)][3 ounce (pack of 1)][3-ounce (2-pack)]
Bright Citrus Deodorant by Earth Mama | Natural and Safe for Sensitive Skin, Pregnancy and Breastfeeding, Contains Organic Calendula 3-Ounce 
Price: $10.99 
Rating: N.A. 
[Description] 
[Features] 
[Reviews] 
[Buy Now]  

Action: click[bright citrus]
Observation: You have clicked bright citrus. 

Action: click[3 ounce (pack of 1)]
Observation: You have clicked 3 ounce (pack of 1). 

Action: click[Buy Now]
"""

# %%
#Rq1 - exemplar COT - prompt1_cot
prompt1_cot = """Webshop 
Instruction:  
i would like a 3 ounce bottle of bright citrus deodorant for sensitive skin, and price lower than 50.00 dollars 

Action: think[Once I find items that are bright citrus deodorant less then 50 dollars, I can check them one by one. For 3 ounce bottle of bright citrus deodorant for sensitive skin, if the item has options 'bright citrus' and '3 ounce (pack of 1)', it will be good to buy.]
Observation: OK.

[Search]  

Action: search[3 ounce bright citrus deodorant sensitive skin]
Observation: 
[Back to Search] 
Page 1 (Total results: 50) 
[Next >] 
[B078GWRC1J] 
Bright Citrus Deodorant by Earth Mama | Natural and Safe for Sensitive Skin, Pregnancy and Breastfeeding, Contains Organic Calendula 3-Ounce 
$10.99 
[B078GTKVXY] 
Ginger Fresh Deodorant by Earth Mama | Natural and Safe for Sensitive Skin, Pregnancy and Breastfeeding, Contains Organic Calendula 3-Ounce 
$10.99 
[B08KBVJ4XN] 
Barrel and Oak - Aluminum-Free Deodorant, Deodorant for Men, Essential Oil-Based Scent, 24-Hour Odor Protection, Cedar & Patchouli Blend, Gentle on Sensitive Skin (Mountain Sage, 2.7 oz, 2-Pack) 
$15.95  

Action: click[B078GWRC1J]
Observation: 
[Back to Search] 
[< Prev] 
scent [assorted scents][bright citrus][calming lavender][ginger fresh][simply non-scents]
size [travel set (4-pack)][3 ounce (pack of 1)][3-ounce (2-pack)]
Bright Citrus Deodorant by Earth Mama | Natural and Safe for Sensitive Skin, Pregnancy and Breastfeeding, Contains Organic Calendula 3-Ounce 
Price: $10.99 
Rating: N.A. 
[Description] 
[Features] 
[Reviews] 
[Buy Now]  

Action: click[bright citrus]
Observation: You have clicked bright citrus. 

Action: click[3 ounce (pack of 1)]
Observation: You have clicked 3 ounce (pack of 1). 

Action: click[Buy Now]
"""

# %%
#Rq1 - exemplar anon COT - prompt1_cot_anon
prompt1_cot_anon = """Webshop 
Instruction:  
i would like a 3 ounce bottle of bright citrus deodorant for sensitive skin, and price lower than 50.00 dollars 

Action: think[Once I find the desired items, I can check them one by one. For 3 ounce bottle of bright citrus deodorant for sensitive skin, if the item has the desired options, it will be good to buy.]
Observation: OK.

[Search]  

Action: search[3 ounce bright citrus deodorant sensitive skin]
Observation: 
[Back to Search] 
Page 1 (Total results: 50) 
[Next >] 
[B078GWRC1J] 
Bright Citrus Deodorant by Earth Mama | Natural and Safe for Sensitive Skin, Pregnancy and Breastfeeding, Contains Organic Calendula 3-Ounce 
$10.99 
[B078GTKVXY] 
Ginger Fresh Deodorant by Earth Mama | Natural and Safe for Sensitive Skin, Pregnancy and Breastfeeding, Contains Organic Calendula 3-Ounce 
$10.99 
[B08KBVJ4XN] 
Barrel and Oak - Aluminum-Free Deodorant, Deodorant for Men, Essential Oil-Based Scent, 24-Hour Odor Protection, Cedar & Patchouli Blend, Gentle on Sensitive Skin (Mountain Sage, 2.7 oz, 2-Pack) 
$15.95  

Action: click[B078GWRC1J]
Observation: 
[Back to Search] 
[< Prev] 
scent [assorted scents][bright citrus][calming lavender][ginger fresh][simply non-scents]
size [travel set (4-pack)][3 ounce (pack of 1)][3-ounce (2-pack)]
Bright Citrus Deodorant by Earth Mama | Natural and Safe for Sensitive Skin, Pregnancy and Breastfeeding, Contains Organic Calendula 3-Ounce 
Price: $10.99 
Rating: N.A. 
[Description] 
[Features] 
[Reviews] 
[Buy Now]  

Action: click[bright citrus]
Observation: You have clicked bright citrus. 

Action: click[3 ounce (pack of 1)]
Observation: You have clicked 3 ounce (pack of 1). 

Action: click[Buy Now]
"""

# %%
#Rq2 - failure - prompt1_failure
prompt1_failure = """Webshop 
Instruction:  
i would like a 3 ounce bottle of bright citrus deodorant for sensitive skin, and price lower than 50.00 dollars 
[Search]  

Action: search[3 ounce bright citrus deodorant sensitive skin]
Observation: 
[Back to Search] 
Page 1 (Total results: 50) 
[Next >] 
[B078GWRC1J] 
Bright Citrus Deodorant by Earth Mama | Natural and Safe for Sensitive Skin, Pregnancy and Breastfeeding, Contains Organic Calendula 3-Ounce 
$10.99 
[B078GTKVXY] 
Ginger Fresh Deodorant by Earth Mama | Natural and Safe for Sensitive Skin, Pregnancy and Breastfeeding, Contains Organic Calendula 3-Ounce 
$10.99 
[B08KBVJ4XN] 
Barrel and Oak - Aluminum-Free Deodorant, Deodorant for Men, Essential Oil-Based Scent, 24-Hour Odor Protection, Cedar & Patchouli Blend, Gentle on Sensitive Skin (Mountain Sage, 2.7 oz, 2-Pack) 
$15.95  

Action: click[B999WW3JKJ]
Observation: Nothing happens

Action: click[B078GWRC1J]
Observation: 
[Back to Search] 
[< Prev] 
scent [assorted scents][bright citrus][calming lavender][ginger fresh][simply non-scents]
size [travel set (4-pack)][3 ounce (pack of 1)][3-ounce (2-pack)]
Bright Citrus Deodorant by Earth Mama | Natural and Safe for Sensitive Skin, Pregnancy and Breastfeeding, Contains Organic Calendula 3-Ounce 
Price: $10.99 
Rating: N.A. 
[Description] 
[Features] 
[Reviews] 
[Buy Now]  

Action: click[ginger]
Observation: Nothing happens

Action: click[bright citrus]
Observation: You have clicked bright citrus. 

Action: click[3 ounce (pack of 1)]
Observation: You have clicked 3 ounce (pack of 1). 

Action: click[Buy Now]
"""

# %%
#Rq2 - failure + exp - prompt1_failure_exp
prompt1_failure_exp = """Webshop 
Instruction:  
i would like a 3 ounce bottle of bright citrus deodorant for sensitive skin, and price lower than 50.00 dollars 
[Search]  

Action: search[3 ounce bright citrus deodorant sensitive skin]
Observation: 
[Back to Search] 
Page 1 (Total results: 50) 
[Next >] 
[B078GWRC1J] 
Bright Citrus Deodorant by Earth Mama | Natural and Safe for Sensitive Skin, Pregnancy and Breastfeeding, Contains Organic Calendula 3-Ounce 
$10.99 
[B078GTKVXY] 
Ginger Fresh Deodorant by Earth Mama | Natural and Safe for Sensitive Skin, Pregnancy and Breastfeeding, Contains Organic Calendula 3-Ounce 
$10.99 
[B08KBVJ4XN] 
Barrel and Oak - Aluminum-Free Deodorant, Deodorant for Men, Essential Oil-Based Scent, 24-Hour Odor Protection, Cedar & Patchouli Blend, Gentle on Sensitive Skin (Mountain Sage, 2.7 oz, 2-Pack) 
$15.95  

Action: click[B999WW3JKJ]
Observation: Nothing happens

Action: think[Nothing happens because I clicked on an invalid item.]
Observation: OK.

Action: click[B078GWRC1J]
Observation: 
[Back to Search] 
[< Prev] 
scent [assorted scents][bright citrus][calming lavender][ginger fresh][simply non-scents]
size [travel set (4-pack)][3 ounce (pack of 1)][3-ounce (2-pack)]
Bright Citrus Deodorant by Earth Mama | Natural and Safe for Sensitive Skin, Pregnancy and Breastfeeding, Contains Organic Calendula 3-Ounce 
Price: $10.99 
Rating: N.A. 
[Description] 
[Features] 
[Reviews] 
[Buy Now]  

Action: click[ginger]
Observation: Nothing happens

Action: think[Nothing happens because I clicked on the incorrect fragrance.]
Observation: OK.

Action: click[bright citrus]
Observation: You have clicked bright citrus. 

Action: click[3 ounce (pack of 1)]
Observation: You have clicked 3 ounce (pack of 1). 

Action: click[Buy Now]
"""

# %%
#Rq2 - placebo - prompt1_placebo
prompt1_placebo = """Webshop 
Instruction:  
i would like a 3 ounce bottle of bright citrus deodorant for sensitive skin, and price lower than 50.00 dollars 
[Search]  

Action: search[3 ounce bright citrus deodorant sensitive skin]
Observation: 
[Back to Search] 
Page 1 (Total results: 50) 
[Next >] 
[B078GWRC1J] 
Bright Citrus Deodorant by Earth Mama | Natural and Safe for Sensitive Skin, Pregnancy and Breastfeeding, Contains Organic Calendula 3-Ounce 
$10.99 
[B078GTKVXY] 
Ginger Fresh Deodorant by Earth Mama | Natural and Safe for Sensitive Skin, Pregnancy and Breastfeeding, Contains Organic Calendula 3-Ounce 
$10.99 
[B08KBVJ4XN] 
Barrel and Oak - Aluminum-Free Deodorant, Deodorant for Men, Essential Oil-Based Scent, 24-Hour Odor Protection, Cedar & Patchouli Blend, Gentle on Sensitive Skin (Mountain Sage, 2.7 oz, 2-Pack) 
$15.95  

Action: think[Take a deep breath and work on this problem step-by-step.]
Observation: OK.

Action: click[B078GWRC1J]
Observation: 
[Back to Search] 
[< Prev] 
scent [assorted scents][bright citrus][calming lavender][ginger fresh][simply non-scents]
size [travel set (4-pack)][3 ounce (pack of 1)][3-ounce (2-pack)]
Bright Citrus Deodorant by Earth Mama | Natural and Safe for Sensitive Skin, Pregnancy and Breastfeeding, Contains Organic Calendula 3-Ounce 
Price: $10.99 
Rating: N.A. 
[Description] 
[Features] 
[Reviews] 
[Buy Now]  

Action: think[Take a deep breath and work on this problem step-by-step.]
Observation: OK.

Action: click[bright citrus]
Observation: You have clicked bright citrus. 

Action: click[3 ounce (pack of 1)]
Observation: You have clicked 3 ounce (pack of 1). 

Action: click[Buy Now]
"""

# %%
EXPT_index = 0
expt_name = ''

if EXPT_index == 0:
    prompt1 = prompt1
    expt_name = '/react_results_500'
elif EXPT_index == 1:
    prompt1 = prompt1_actonly
    expt_name = '/actonly_result_500'
elif EXPT_index == 2:
    prompt1 = prompt1_cot
    expt_name = '/cot_results_500'
elif EXPT_index == 3:
    prompt1 = prompt1_cot_anon
    expt_name = '/cot_anon_results_500'
elif EXPT_index == 4:
    prompt1 = prompt1_failure
    expt_name = '/failure_results_500'
elif EXPT_index == 5:
    prompt1 = prompt1_failure_exp
    expt_name = '/failure_exp_results_500'
elif EXPT_index == 6:
    prompt1 = prompt1_placebo
    expt_name = '/placebo_results_500'

# %%
SAVE_PATH= f"./test_webshopoutput/{LLM_MODEL}"
os.makedirs(os.path.dirname(SAVE_PATH), exist_ok=True)

expt_file_path = SAVE_PATH + expt_name + '.txt'

llm = LLM(LLM_MODEL, SAVE_PATH + expt_name + '.json')

# %%
def webshop_run(idx, prompt, to_print=True):
  action = 'reset'
  init_prompt = prompt
  prompt = ''
  ACTIONS_LIMIT = 15
  for i in range(ACTIONS_LIMIT):
    try:
      res = env.step(idx, action)
      observation = res[0]
    except AssertionError:
      observation = 'Invalid action!'

    if action.startswith('think'):
      observation = 'OK.'


    if to_print:
      print(f'Action: {action}\nObservation: {observation}\n')
      sys.stdout.flush()
    if i:
      prompt += f' {action}\nObservation: {observation}\n\nAction:'
    else:
      prompt += f'{observation}\n\nAction:'
    
    if res[2]:  
      return res[1]

    action = llm.llm(init_prompt + prompt[-(6400-len(init_prompt)):], stop=['\n']).lstrip(' ')

  return 0

def run_episodes(prompt, n=101, expt_file_path=None):
  rs = []
  cnt = 0
  for i in range(100, n):
    print('-----------------')
    print(i)
    try:
      r = webshop_run(f'fixed_{i}', prompt, to_print=True)
    except AssertionError:
      r = 0
      cnt += 1
    rs.append(r)
    if (i+1) % 1 == 0:
      r, sr, fr = sum(rs) / len(rs), len([_ for _ in rs if _ == 1]) / len(rs), cnt / len(rs)
      print(i+1, r, sr, fr)
      print('-------------')
  r, sr, fr = sum(rs) / len(rs), len([_ for _ in rs if _ == 1]) / n, cnt / n
  
  with open(expt_file_path, 'w') as f:
    f.write(f"{r}, {sr}, {fr}")
  
  print(r, sr, fr)
  return rs

# %%
if not os.path.exists(expt_file_path):
    os.makedirs(os.path.dirname(expt_file_path), exist_ok=True)
res1 = run_episodes(prompt1, 500, expt_file_path)
# Out:
# -----------------
# 100
# Action: reset
# Observation:
# WebShop
# Instruction:
# i want a rca cable that is high def, and price lower than 30.00 dollars
# [Search]
# /tmp/ipykernel_9882/3825535868.py:54: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   texts = html_obj.findAll(text=True)
# Action: search[rca high def cable]
# Observation:
# [Back to Search]
# Page 1 (Total results: 50)
# [Next >]
# [B00UN9GR8W]
# 8' FT RCA Cable 3 RCA Males Each End Composite Audio Video Gold Shielded RG59 Coaxial Stereo A/V Dubbing Cable Heavy Duty Fully R/Y/W Triple A/V Stereo Digital Signal Hook-Up RG-59 Jumper with Plug Connectors
# $11.51
# [B06Y44FL9J]
# LINDY 36920 0.5m DisplayPort to HDMI 10.2G Cable, Black
# $17.31
# [B096L3FNMR]
# 4-Channel Wireless Bluetooth Power Amplifier - 1000W Stereo Speaker Home Audio Receiver w/FM Radio, USB, Headphone, 2 Mic w/Echo, Front Loading CD DVD Player, LED, Rack Mount - Pyle PD1000BA.5
# $242.99
#
# Action: click[B00UN9GR8W]
# Observation:
# [Back to Search]
# [< Prev]
# 8' FT RCA Cable 3 RCA Males Each End Composite Audio Video Gold Shielded RG59 Coaxial Stereo A/V Dubbing Cable Heavy Duty Fully R/Y/W Triple A/V Stereo Digital Signal Hook-Up RG-59 Jumper with Plug Connectors
# Price: $11.51
# Rating: N.A.
# [Description]
# [Features]
# [Reviews]
# [Attributes]
# [Buy Now]
#
# Action: click[B00UN9GR8W]
# Observation: Invalid action!
#
# Action: click[B00UN9GR8W]
# Observation: Invalid action!
#
# Action: click[Buy Now]
# Observation: Your score (min 0.0, max 1.0): 0.5
#
# 101 0.5 0.0 0.0
# -------------
# -----------------
# 101
# Action: reset
# Observation:
# WebShop
# Instruction:
# i want mivofun 11pcs cute dinosaur cake toppers for a baby shower, and price lower than 40.00 dollars
# [Search]
#
# Action: search[mivofun 11pcs cute dinosaur cake toppers baby shower]
# Observation:
# [Back to Search]
# Page 1 (Total results: 50)
# [Next >]
# [B08PBDHVN8]
# Amosfun 27Pcs Glitter Heart Cupcake Toppers Love Cake Toppers Fruit Dessert Toothpick Cake Picks for New Year Weeding Birthday Valentines Day Cake Decoration Assorted Color
# $17.59
# [B07TVMCK3F]
# Ercadio 24 Pack Soccer Cupcake Toppers Black Glitter Football Cupcake Topper Sports Theme Soccer Party Baby Shower Cake Decoration
# $6.99
# [B08W2WTW4Z]
# jojofuny 27pcs Checkered Flag Race Flag Cupcake Topper Picks Toothpick Flag Dinner Flags Chequered Flag Race Car Themed Party Supplies for Car Lover Cake Decorations
# $9.49
#
# Action: click[B07TVMCK3F]
# Observation:
# [Back to Search]
# [< Prev]
# Ercadio 24 Pack Soccer Cupcake Toppers Black Glitter Football Cupcake Topper Sports Theme Soccer Party Baby Shower Cake Decoration
# Price: $6.99
# Rating: N.A.
# [Description]
# [Features]
# [Reviews]
# [Attributes]
# [Buy Now]
#
# Action: click[Buy Now]
# Observation: Your score (min 0.0, max 1.0): 1.0
#
# 102 0.75 0.5 0.0
# -------------
# -----------------
# 102
# Action: reset
# Observation:
# WebShop
# Instruction:
# i am in need of elastic waist winter active running joggers pants of small size and dark grey color, and price lower than 70.00 dollars
# [Search]
#
# Action: search[elastic waist winter active running joggers pants small dark grey]
# Observation:
# [Back to Search]
# Page 1 (Total results: 50)
# [Next >]
# [B09QCVCYVY]
# Burband Womens High Waist Bike Shorts Tummy Control Workout Yoga Pants Running Exercise Running Shorts with Side Pockets
# $6.82
# [B09MSZ4VS8]
# Goldweather Women Winter Leggings Printed Warm Fleece Lined Yoga Pants Trousers Thermal High Waist Thicken Cashmere Tights (Navy, L)
# $20.99
# [B099231V35]
# Mens Casual Cargo Pants Hi Vis Viz Reflective Overalls High Visibility Safe Work Pants Outdoor Hiking Trousers Big and Tall
# $16.79
#
# Action: click[B09QCVCYVY]
# Observation:
# [Back to Search]
# [< Prev]
# color [black][blue][dark gray][gray][navy][red][silver]
# size [small][medium][large][x-large][xx-large]
# Burband Womens High Waist Bike Shorts Tummy Control Workout Yoga Pants Running Exercise Running Shorts with Side Pockets
# Price: $6.82
# Rating: N.A.
# [Description]
# [Features]
# [Reviews]
# [Attributes]
# [Buy Now]
#
# Action: click[small]
# Observation: You have clicked small.
#
# Action: click[Buy Now]
# Observation: Your score (min 0.0, max 1.0): 0.75
#
# 103 0.75 0.3333333333333333 0.0
# -------------
# -----------------
# 103
# Action: reset
# Observation:
# WebShop
# Instruction:
# i am looking for a 32gb 1tb ssd pcle nvme m.2 size intel core minis
# [Search]
#
# Action: search[32gb 1tb ssd pcle nvme m.2 intel core minis]
# Observation:
# [Back to Search]
# Page 1 (Total results: 50)
# [Next >]
# [B0871VQT3Q]
# Computer & Tablet Y12 4G Phone Call Tablet PC, 10.1 inch, 2GB+32GB, Android 7.0 MTK6753 Octa-core up to 1.6GHz, WiFi, Bluetooth, OTG, GPS(Gold) (Color : Rose Gold)
# $100.0
# [B09NMZS7HK]
# EWEAT R10 II 4K UHD Media Player HDD Home Cinema VS10 Image Quality Engine HDR10+ 2GB+32GB Android Media Box with DAC Audio
# $599.0
# [B09RLQR5NP]
# M&M's Peanut Butter Chocolate Fun Size Packs American Candy In A Variety Of Fun Colors Bulk Party Mix Packaged In Resealable Wholesale Pantry Bag 2 Lbs. (32 Oz)
# $29.99
#
# Action: click[B0871VQT3Q]
# Observation:
# [Back to Search]
# [< Prev]
# Computer & Tablet Y12 4G Phone Call Tablet PC, 10.1 inch, 2GB+32GB, Android 7.0 MTK6753 Octa-core up to 1.6GHz, WiFi, Bluetooth, OTG, GPS(Gold) (Color : Rose Gold)
# Price: $100.0
# Rating: N.A.
# [Description]
# [Features]
# [Reviews]
# [Attributes]
# [Buy Now]
#
# Action: click[B09RLQR5NP]
# Observation: Invalid action!
#
# Action: click[B09RLQR5NP]
# Observation: Invalid action!
#
# Action: click[B09RLQR5NP]
# Observation: Invalid action!
#
# Action: click[B09RLQR5NP]
# Observation: Invalid action!
#
# Action: click[B09RLQR5NP]
# Observation: Invalid action!
#
# Action: click[B09RLQR5NP]
# Observation: Invalid action!
#
# Action: click[B09RLQR5NP]
# Observation: Invalid action!
#
# Action: click[B09RLQR5NP]
# Observation: Invalid action!
#
# Action: click[B09RLQR5NP]
# Observation: Invalid action!
#
# Action: click[B09RLQR5NP]
# Observation: Invalid action!
#
# Action: click[B09RLQR5NP]
# Observation: Invalid action!
#
# Action: click[B09RLQR5NP]
# Observation: Invalid action!
#
# 104 0.5625 0.25 0.0
# -------------
# -----------------
# 104
# Action: reset
# Observation:
# WebShop
# Instruction:
# looking for an easy to deliver vintage barbecue sauce needle sleeve white women's halloween t-shirt by tomorrow? forgot to machine wash, and price lower than 30.00 dollars
# [Search]
#
# Action: search[vintage barbecue sauce needle sleeve white women's halloween t-shirt]
# Observation:
# [Back to Search]
# Page 1 (Total results: 50)
# [Next >]
# [B09QGK5XHZ]
# WENKOMG1 Men's Long Sleeve Undershirt with Mask Turtleneck Hooded T-Shirt Solid Color Workout Tops Zipper Side Slit Shirts Slim Fit Sweatshirt Spring/Summer Tee Shirts(Gray,)
# $8.39
# [B09QQP3356]
# HAUKLIE Men's Sports Waffle Ribbed Polo Shirts Summer Short Sleeve Cotton Muscle Quarter-Zip Henley T-Shirt Tunics Tops
# $10.99
# [B09Q37JQZ6]
# Women's Sexy Swimsuit One Piece High Neck Halter Bikini Floral Stiching See Through Monokini Tummy Control Beachwear
# $10.99 to $18.99
#
# Action: click[B09QGK5XHZ]
# Observation:
# [Back to Search]
# [< Prev]
# WENKOMG1 Men's Long Sleeve Undershirt with Mask Turtleneck Hooded T-Shirt Solid Color Workout Tops Zipper Side Slit Shirts Slim Fit Sweatshirt Spring/Summer Tee Shirts(Gray,)
# Price: $8.39
# Rating: N.A.
# [Description]
# [Features]
# [Reviews]
# [Attributes]
# [Buy Now]
#
# Action: click[B09QGK5XHZ]
# Observation: Invalid action!
#
# Action: click[B09QGK5XHZ]
# Observation: Invalid action!
#
# Action: click[B09QGK5XHZ]
# Observation: Invalid action!
#
# Action: click[B09QGK5XHZ]
# Observation: Invalid action!
#
# Action: click[B09QGK5XHZ]
# Observation: Invalid action!
#
# Action: click[B09QGK5XHZ]
# Observation: Invalid action!
#
# Action: click[B09QGK5XHZ]
# Observation: Invalid action!
#
# Action: click[B09QGK5XHZ]
# Observation: Invalid action!
#
# Action: click[B09QGK5XHZ]
# Observation: Invalid action!
#
# Action: click[B09QGK5XHZ]
# Observation: Invalid action!
#
# Action: click[B09QGK5XHZ]
# Observation: Invalid action!
#
# Action: click[B09QGK5XHZ]
# Observation: Invalid action!
#
# 105 0.45 0.2 0.0
# -------------
# -----------------
# 105
# Action: reset
# Observation:
# WebShop
# Instruction:
# i'm looking for black colored high quality hair removal cream it easy to use, and price lower than 40.00 dollars
# [Search]
#
# Action: search[black hair removal cream easy to use]
# Observation:
# [Back to Search]
# Page 1 (Total results: 50)
# [Next >]
# [B07B41K2VV]
# Nair Hair Remover Sensitive Formula (Pack of 2)
# $16.53
# [B08NB29KXH]
# Seki Japan Face Beauty Trimmer, Women's Facial Razor, Disposable Facial Hair Removal Groomer, with Safety Cover 3 Pieces
# $8.1
# [B07CBFM96F]
# Garnier Hair Care Fructis Style Pixie Play Crafting Cream, 2 Count, Texture, 4 Oz
# $6.98
#
# Action: click[B07B41K2VV]
# Observation:
# [Back to Search]
# [< Prev]
# Nair Hair Remover Sensitive Formula (Pack of 2)
# Price: $16.53
# Rating: N.A.
# [Description]
# [Features]
# [Reviews]
# [Attributes]
# [Buy Now]
#
# Action: click[B07B41K2VV]
# Observation: Invalid action!
#
# Action: click[B07B41K2VV]
# Observation: Invalid action!
#
# Action: click[B07B41K2VV]
# Observation: Invalid action!
#
# Action: click[B07B41K2VV]
# Observation: Invalid action!
#
# Action: click[B07B41K2VV]
# Observation: Invalid action!
#
# Action: click[B07B41K2VV]
# Observation: Invalid action!
#
# Action: click[B07B41K2VV]
# Observation: Invalid action!
#
# Action: click[B07B41K2VV]
# Observation: Invalid action!
#
# Action: click[B07B41K2VV]
# Observation: Invalid action!
#
# Action: click[B07B41K2VV]
# Observation: Invalid action!
#
# Action: click[B07B41K2VV]
# Observation: Invalid action!
#
# Action: click[B07B41K2VV]
# Observation: Invalid action!
#
# 106 0.375 0.16666666666666666 0.0
# -------------
# -----------------
# 106
# Action: reset
# Observation:
# WebShop
# Instruction:
# i am looking for
# Rating: N.A.
# [Description]
# [Features]
# [Reviews]
# [Attributes]
# [Buy Now]
#
# Action: click[10]
# Observation: You have clicked 10.
#
# Action: click[Buy Now]
# Observation: Your score (min 0.0, max 1.0): 0.75
#
# 109 0.42592592592592593 0.1111111111111111 0.0
# -------------
# -----------------
# 109
# Action: reset
# Observation:
# WebShop
# Instruction:
# i need a wall lamp with clear glass, and price lower than 180.00 dollars
# [Search]
#
# Action: search[clear glass wall lamp]
# Observation:
# [Back to Search]
# Page 1 (Total results: 50)
# [Next >]
# [B003HBR86S]
# Sea Gull Lighting 85200-12 Wynfield One-Light Outdoor Wall Lantern with Clear Beveled Glass Panels, Black Finish
# $61.17
# [B0928LGTVF]
# Fanyate Antique Industrial Wall Sconce, 2-Light Bathroom Light Fixture Oil Rubbed Bronze Vanity Light with Clear Glass Shade Suitable for Bathroom Living Room Hallway ORB, 2 Pack
# $113.99
# [B08D74SKT2]
# 4-Light Wall Sconces Vintage Bathroom Vanity Light Over Mirror in Brushed Nickel Finish
# $119.0
#
# Action: click[B003HBR86S]
# Observation:
# [Back to Search]
# [< Prev]
# Sea Gull Lighting 85200-12 Wynfield One-Light Outdoor Wall Lantern with Clear Beveled Glass Panels, Black Finish
# Price: $61.17
# Rating: N.A.
# [Description]
# [Features]
# [Reviews]
# [Attributes]
# [Buy Now]
#
# Action: click[Description]
# Observation:
# [Back to Search]
# [< Prev]
# The Sea Gull Lighting Wynfield one light outdoor wall fixture in black enhances the beauty of your property, makes your home safer and more secure, and increases the number of pleasurable hours you spend outdoors. The Wynfield collection by Sea Gull Lighting complements classical home designs with its soft curves and colonial accents. A Black Powdercoat finish over a durable cast aluminum body adds dependable quality to an enduring style. Either Frosted glass or Clear Beveled glass give the fixtures distinct appeal. The assortment includes small, medium and large one-light outdoor wall lanterns, a two-light outdoor wall lantern, a two-light, outdoor post lantern and a two-light outdoor ceiling flush mount. The fixtures with Frosted glass are also available in an ENERGY STAR-qualified fluorescent version, and the one-light fixtures with Clear Beveled glass can easily convert to LED by purchasing LED replacement lamps sold separately.
#
# Action: click[Buy Now]
# Observation: Invalid action!
#
# Action: click[B003HBR86S]
# Observation:
# [Back to Search]
# [< Prev]
# The Sea Gull Lighting Wynfield one light outdoor wall fixture in black enhances the beauty of your property, makes your home safer and more secure, and increases the number of pleasurable hours you spend outdoors. The Wynfield collection by Sea Gull Lighting complements classical home designs with its soft curves and colonial accents. A Black Powdercoat finish over a durable cast aluminum body adds dependable quality to an enduring style. Either Frosted glass or Clear Beveled glass give the fixtures distinct appeal. The assortment includes small, medium and large one-light outdoor wall lanterns, a two-light outdoor wall lantern, a two-light, outdoor post lantern and a two-light outdoor ceiling flush mount. The fixtures with Frosted glass are also available in an ENERGY STAR-qualified fluorescent version, and the one-light fixtures with Clear Beveled glass can easily convert to LED by purchasing LED replacement lamps sold separately.
#
# Action: click[B0928LGTVF]
# Observation:
# [Back to Search]
# [< Prev]
# The Sea Gull Lighting Wynfield one light outdoor wall fixture in black enhances the beauty of your property, makes your home safer and more secure, and increases the number of pleasurable hours you spend outdoors. The Wynfield collection by Sea Gull Lighting complements classical home designs with its soft curves and colonial accents. A Black Powdercoat finish over a durable cast aluminum body adds dependable quality to an enduring style. Either Frosted glass or Clear Beveled glass give the fixtures distinct appeal. The assortment includes small, medium and large one-light outdoor wall lanterns, a two-light outdoor wall lantern, a two-light, outdoor post lantern and a two-light outdoor ceiling flush mount. The fixtures with Frosted glass are also available in an ENERGY STAR-qualified fluorescent version, and the one-light fixtures with Clear Beveled glass can easily convert to LED by purchasing LED replacement lamps sold separately.
#
# Action: click[Buy Now]
# Observation: Invalid action!
#
# Action: click[B08D74SKT2]
# Observation:
# [Back to Search]
# [< Prev]
# The Sea Gull Lighting Wynfield one light outdoor wall fixture in black enhances the beauty of your property, makes your home safer and more secure, and increases the number of pleasurable hours you spend outdoors. The Wynfield collection by Sea Gull Lighting complements classical home designs with its soft curves and colonial accents. A Black Powdercoat finish over a durable cast aluminum body adds dependable quality to an enduring style. Either Frosted glass or Clear Beveled glass give the fixtures distinct appeal. The assortment includes small, medium and large one-light outdoor wall lanterns, a two-light outdoor wall lantern, a two-light, outdoor post lantern and a two-light outdoor ceiling flush mount. The fixtures with Frosted glass are also available in an ENERGY STAR-qualified fluorescent version, and the one-light fixtures with Clear Beveled glass can easily convert to LED by purchasing LED replacement lamps sold separately.
#
# Action: click[< Prev]
# Observation:
# [Back to Search]
# [< Prev]
# Sea Gull Lighting 85200-12 Wynfield One-Light Outdoor Wall Lantern with Clear Beveled Glass Panels, Black Finish
# Price: $61.17
# Rating: N.A.
# [Description]
# [Features]
# [Reviews]
# [Attributes]
# [Buy Now]
#
# Action: click[< Prev]
# Observation:
# [Back to Search]
# Page 1 (Total results: 50)
# [Next >]
# [B003HBR86S]
# Sea Gull Lighting 85200-12 Wynfield One-Light Outdoor Wall Lantern with Clear Beveled Glass Panels, Black Finish
# $61.17
# [B0928LGTVF]
# Fanyate Antique Industrial Wall Sconce, 2-Light Bathroom Light Fixture Oil Rubbed Bronze Vanity Light with Clear Glass Shade Suitable for Bathroom Living Room Hallway ORB, 2 Pack
# $113.99
# [B08D74SKT2]
# 4-Light Wall Sconces Vintage Bathroom Vanity Light Over Mirror in Brushed Nickel Finish
# $119.0
#
# Action: click[Buy Now]
# Observation: Invalid action!
#
# Action: click[< Prev]
# Observation: Invalid action!
#
# Action: click[Buy Now]
# Observation: Invalid action!
#
# Action: click[< Prev]
# Observation: Invalid action!
#
# 110 0.38333333333333336 0.1 0.0
# -------------
# -----------------
# 110
# Action: reset
# Observation:
# WebShop
# Instruction:
# i want a black and high quality cenglings womens cowl neck sweatshirt, and price lower than 50.00 dollars
# [Search]
#
# Action: search[black high quality cenglings women's cowl neck sweatshirt]
# Observation:
# [Back to Search]
# Page 1 (Total results: 50)
# [Next >]
# [B09KP78G37]
# Women Faux Fur Lined Jacket Coat Winter Warm Thick Fleece Outwear Trench Zipper Plus Size Long Sleeve Plush Overcoat
# $47.41 to $59.07
# [B09Q37JQZ6]
# Women's Sexy Swimsuit One Piece High Neck Halter Bikini Floral Stiching See Through Monokini Tummy Control Beachwear
# $10.99 to $18.99
# [B09P5CRVQ6]
# Womens Tops Casual, Sweatshirt for Women Graphic, Womens Sweatshirt Hoodie, Women Love Print Sweatshirt Long Sleeve Cute Heart Sweater Pullover Tops Blouse
# $22.78
#
# Action: click[B09KP78G37]
# Observation:
# [Back to Search]
# [< Prev]
# color [black][navy][red][yellow]
# size [small][medium][large][x-large][xx-large][3x-large]
# Women Faux Fur Lined Jacket Coat Winter Warm Thick Fleece Outwear Trench Zipper Plus Size Long Sleeve Plush Overcoat
# Price: $47.41 to $59.07
# Rating: N.A.
# [Description]
# [Features]
# [Reviews]
# [Attributes]
# [Buy Now]
#
# Action: click[black]
# Observation: You have clicked black.
#
# Action: click[black]
# Observation: You have clicked black.
#
# Action: click[black]
# Observation: You have clicked black.
#
# Action: click[black]
# Observation: You have clicked black.
#
# Action: click[black]
# Observation: You have clicked black.
#
# Action: click[black]
# Observation: You have clicked black.
#
# Action: click[black]
# Observation: You have clicked black.
#
# Action: click[black]
# Observation: You have clicked black.
#
# Action: click[black]
# Observation: You have clicked black.
#
# Action: click[black]
# Observation: You have clicked black.
#
# Action: click[black]
# Observation: You have clicked black.
#
# Action: click[black]
# Observation: You have clicked black.
#
# 111 0.3484848484848485 0.09090909090909091 0.0
# -------------
# -----------------
# 111
# Action: reset
# Observation:
# WebShop
# Instruction:
# i need a s20 tv sound bar that comes with a wireless bluetooth speaker, and price lower than 70.00 dollars
# [Search]
#
# Action: search[s20 tv sound bar wireless bluetooth speaker]
# Observation:
# [Back to Search]
# Page 1 (Total results: 50)
# [Next >]
# [B095C2ZMTX]
# Mingbao Sound Quality Hi-Fi Stereo Speaker Wireless Bluetooth Soundbar Home Theater TV Strong Bass Sound Bar + Remote Control
# $100.0
# [B09B4YH4RG]
# Memphis Audio MXASB35 35" 10-Speaker ATV/UTV Sound Bar Bundle with Bar 2.1 Deep Bass Home Theater Bluetooth Soundbar with Wireless Sub Movies/Music
# $699.95
# [B07VHJY9KJ]
# Sound Bar,TV Bluetooth Speaker Portable Dual Loudspeakers Screen 3D Sound Effects, for TV, PC, Cell Phone, Tablets Projector
# $100.0
#
# Action: click[B095C2ZMTX]
# Observation:
# [Back to Search]
# [< Prev]
# Mingbao Sound Quality Hi-Fi Stereo Speaker Wireless Bluetooth Soundbar Home Theater TV Strong Bass Sound Bar + Remote Control
# Price: $100.0
# Rating: N.A.
# [Description]
# [Features]
# [Reviews]
# [Attributes]
# [Buy Now]
#
# Action: click[Back to Search]
# Observation:
# WebShop
# Instruction:
# i need a s20 tv sound bar that comes with a wireless bluetooth speaker, and price lower than 70.00 dollars
# [Search]
#
# Action: search[s20 tv sound bar wireless bluetooth speaker]
# Observation:
# [Back to Search]
# Page 1 (Total results: 50)
# [Next >]
# [B095C2ZMTX]
# Mingbao Sound Quality Hi-Fi Stereo Speaker Wireless Bluetooth Soundbar Home Theater TV Strong Bass Sound Bar + Remote Control
# $100.0
# [B09B4YH4RG]
# Memphis Audio MXASB35 35" 10-Speaker ATV/UTV Sound Bar Bundle with Bar 2.1 Deep Bass Home Theater Bluetooth Soundbar with Wireless Sub Movies/Music
# $699.95
# [B07VHJY9KJ]
# Sound Bar,TV Bluetooth Speaker Portable Dual Loudspeakers Screen 3D Sound Effects, for TV, PC, Cell Phone, Tablets Projector
# $100.0
#
# Action: click[B09B4YH4RG]
# Observation:
# [Back to Search]
# [< Prev]
# Memphis Audio MXASB35 35" 10-Speaker ATV/UTV Sound Bar Bundle with Bar 2.1 Deep Bass Home Theater Bluetooth Soundbar with Wireless Sub Movies/Music
# Price: $699.95
# Rating: N.A.
# [Description]
# [Features]
# [Reviews]
# [Attributes]
# [Buy Now]
#
# Action: click[B07VHJY9KJ]
# Observation: Invalid action!
#
# Action: click[B07VHJY9KJ]
# Observation: Invalid action!
#
# Action: click[B07VHJY9KJ]
# Observation: Invalid action!
#
# Action: click[B07VHJY9KJ]
# Observation: Invalid action!
#
# Action: click[B07VHJY9KJ]
# Observation: Invalid action!
#
# Action: click[B07VHJY9KJ]
# Observation: Invalid action!
#
# Action: click[B07VHJY9KJ]
# Observation: Invalid action!
#
# Action: click[B07VHJY9KJ]
# Observation: Invalid action!
#
# Action: click[B07VHJY9KJ]
# Observation: Invalid action!
#
# 112 0.3194444444444445 0.08333333333333333 0.0
# -------------
# -----------------
# 112
# Action: reset
# Observation:
# WebShop
# Instruction:
# i am looking for a headphones case that is apple compatible and is navy blue colored, and price lower than 20.00 dollars
# [Search]
#
# Action: search[apple compatible navy blue headphones case]
# Observation:
# [Back to Search]
# Page 1 (Total results: 50)
# [Next >]
# [B07VVVDRCX]
# iPad Case Fit 2018/2017 iPad 9.7 6th/5th Generation - 360 Degree Rotating iPad Air Case Cover with Auto Wake/Sleep Compatible with Apple iPad 9.7 Inch 2018/2017 (National Wind)
# $12.99
# [B098SV78BW]
# Square iPhone 11 Case,Tzomsze Cute Full Camera Lens Protection & Electroplate Reinforced Corners Shockproof Edge Bumper Case Compatible with iPhone 11 [6.1 inches] -Candy Pink
# $10.59
# [B09B7551X2]
# MNBVCXZ Watch Bands Compatible for Apple Watch Band 44mm 45mm 40mm 41mm with Protective Case for Men & Women, Sport Waterproof Strap for iWatch SE Series 7/6/5/4 (40mm 41mm,Midnight blue)
# $10.99
#
# Action: click[B07VVVDRCX]
# Observation:
# [Back to Search]
# [< Prev]
# color [butterfly][cambridge blue][coconut trees][coffee letter][green][national wind][ostrich][pear flower][pink][pink flowers][red][red mandala][red-3][rose][sunset][coast coconut trees][peach blossom]
# iPad Case Fit 2018/2017 iPad 9.7 6th/5th Generation - 360 Degree Rotating iPad Air Case Cover with Auto Wake/Sleep Compatible with Apple iPad 9.7 Inch 2018/2017 (National Wind)
# Price: $12.99
# Rating: N.A.
# [Description]
# [Features]
# [Reviews]
# [Attributes]
# [Buy Now]
#
# Action: click[Attributes]
# Observation:
# [Back to Search]
# [< Prev]
#  case cover
#  compatible apple
# electronics
# online game services
# Electronics › Computers & Accessories › Tablet Accessories › Bags, Cases & Sleeves › Cases
#
# Action: click[Back to Search]
# Observation:
# WebShop
# Instruction:
# i am looking for a headphones case that is apple compatible and is navy blue colored, and price lower than 20.00 dollars
# [Search]
#
# Action: search[apple compatible navy blue headphones case]
# Observation:
# [Back to Search]
# Page 1 (Total results: 50)
# [Next >]
# [B07VVVDRCX]
# iPad Case Fit 2018/2017 iPad 9.7 6th/5th Generation - 360 Degree Rotating iPad Air Case Cover with Auto Wake/Sleep Compatible with Apple iPad 9.7 Inch 2018/2017 (National Wind)
# $12.99
# [B098SV78BW]
# Square iPhone 11 Case,Tzomsze Cute Full Camera Lens Protection & Electroplate Reinforced Corners Shockproof Edge Bumper Case Compatible with iPhone 11 [6.1 inches] -Candy Pink
# $10.59
# [B09B7551X2]
# MNBVCXZ Watch Bands Compatible for Apple Watch Band 44mm 45mm 40mm 41mm with Protective Case for Men & Women, Sport Waterproof Strap for iWatch SE Series 7/6/5/4 (40mm 41mm,Midnight blue)
# $10.99
#
# Action: click[B09B7551X2]
# Observation:
# [Back to Search]
# [< Prev]
# MNBVCXZ Watch Bands Compatible for Apple Watch Band 44mm 45mm 40mm 41mm with Protective Case for Men & Women, Sport Waterproof Strap for iWatch SE Series 7/6/5/4 (40mm 41mm,Midnight blue)
# Price: $10.99
# Rating: N.A.
# [Description]
# [Features]
# [Reviews]
# [Attributes]
# [Buy Now]
#
# Action: click[Attributes]
# Observation:
# [Back to Search]
# [< Prev]
#  apple watch
#  easy install
#  compatible apple
#  screen protector
# electronics
# wearable technology
# Cell Phones & Accessories › Accessories › Smartwatch Accessories › Smartwatch Bands
#
# Action: click[Back to Search]
# Observation:
# WebShop
# Instruction:
# i am looking for a headphones case that is apple compatible and is navy blue colored, and price lower than 20.00 dollars
# [Search]
#
# Action: search[apple compatible navy blue headphones case]
# Observation:
# [Back to Search]
# Page 1 (Total results: 50)
# [Next >]
# [B07VVVDRCX]
# iPad Case Fit 2018/2017 iPad 9.7 6th/5th Generation - 360 Degree Rotating iPad Air Case Cover with Auto Wake/Sleep Compatible with Apple iPad 9.7 Inch 2018/2017 (National Wind)
# $12.99
# [B098SV78BW]
# Square iPhone 11 Case,Tzomsze Cute Full Camera Lens Protection & Electroplate Reinforced Corners Shockproof Edge Bumper Case Compatible with iPhone 11 [6.1 inches] -Candy Pink
# $10.59
# [B09B7551X2]
# MNBVCXZ Watch Bands Compatible for Apple Watch Band 44mm 45mm 40mm 41mm with Protective Case for Men & Women, Sport Waterproof Strap for iWatch SE Series 7/6/5/4 (40mm 41mm,Midnight blue)
# $10.99
#
# Action: click[B098SV78BW]
# Observation:
# [Back to Search]
# [< Prev]
# color [electroplate black-11][electroplate dark green-11][electroplate green-11][electroplate pink-11][electroplate purple-11][electroplate red-11][electroplate sea blue-11][electroplate whitte-11]
# Square iPhone 11 Case,Tzomsze Cute Full Camera Lens Protection & Electroplate Reinforced Corners Shockproof Edge Bumper Case Compatible with iPhone 11 [6.1 inches] -Candy Pink
# Price: $10.59
# Rating: N.A.
# [Description]
# [Features]
# [Reviews]
# [Attributes]
# [Buy Now]
#
# Action: click[Attributes]
# Observation:
# [Back to Search]
# [< Prev]
#  camera lens
#  phone case
#  lens protector
#  wireless charging
#  heavy duty
# electronics
# iphone accessories
# Cell Phones & Accessories › Cases, Holsters & Sleeves › Basic Cases
#
# Action: click[Back to Search]
# Observation:
# WebShop
# Instruction:
# i am looking for a headphones case that is apple compatible and is navy blue colored, and price lower than 20.00 dollars
# [Search]
#
# Action: click[B078GWRC1J]
# Observation:
# WebShop
# Instruction:
# i am looking for a headphones case that is apple compatible and is navy blue colored, and price lower than 20.00 dollars
# [Search]
#
# Action: click[B078GWRC1J]
# Observation:
# WebShop
# Instruction:
# i am looking for a headphones case that is apple compatible and is navy blue colored, and price lower than 20.00 dollars
# [Search]
#
# 113 0.2948717948717949 0.07692307692307693 0.0
# -------------
# -----------------
# 113
# Action: reset
# Observation:
# WebShop
# Instruction:
# i need a pair of low rise yellow briefs in a large, and price lower than 50.00 dollars
# [Search]
#
# Action: search[low rise yellow briefs large]
# Observation:
# [Back to Search]
# Page 1 (Total results: 50)
# [Next >]
# [B09
# Rating: N.A.
# [Description]
# [Features]
# [Reviews]
# [Attributes]
# [Buy Now]
#
# Action: click[Buy Now]
# Observation: Your score (min 0.0, max 1.0): 0.25
#
# 116 0.25520833333333337 0.0625 0.0
# -------------
# -----------------
# 116
# Action: reset
# Observation:
# WebShop
# Instruction:
# i'm looking for a mini pc intel core desktop computer which supports with windows 11, and price lower than 740.00 dollars
# [Search]
#
# Action: search[mini pc intel core windows 11]
# Observation:
# [Back to Search]
# Page 1 (Total results: 50)
# [Next >]
# [B0871VQT3Q]
# Computer & Tablet Y12 4G Phone Call Tablet PC, 10.1 inch, 2GB+32GB, Android 7.0 MTK6753 Octa-core up to 1.6GHz, WiFi, Bluetooth, OTG, GPS(Gold) (Color : Rose Gold)
# $100.0
# [B06Y44FL9J]
# LINDY 36920 0.5m DisplayPort to HDMI 10.2G Cable, Black
# $17.31
# [B01M7U6F8T]
# Adjustable Cell Phone Stand, Lamicall Desk Phone Holder, Cradle, Dock, Compatible with All 4-8'' Phones, Office Accessories, All Android Smartphone - Black
# $12.99
#
# Action: click[B0871VQT3Q]
# Observation:
# [Back to Search]
# [< Prev]
# Computer & Tablet Y12 4G Phone Call Tablet PC, 10.1 inch, 2GB+32GB, Android 7.0 MTK6753 Octa-core up to 1.6GHz, WiFi, Bluetooth, OTG, GPS(Gold) (Color : Rose Gold)
# Price: $100.0
# Rating: N.A.
# [Description]
# [Features]
# [Reviews]
# [Attributes]
# [Buy Now]
#
# Action: click[Back to Search]
# Observation:
# WebShop
# Instruction:
# i'm looking for a mini pc intel core desktop computer which supports with windows 11, and price lower than 740.00 dollars
# [Search]
#
# Action: search[mini pc intel core windows 11]
# Observation:
# [Back to Search]
# Page 1 (Total results: 50)
# [Next >]
# [B0871VQT3Q]
# Computer & Tablet Y12 4G Phone Call Tablet PC, 10.1 inch, 2GB+32GB, Android 7.0 MTK6753 Octa-core up to 1.6GHz, WiFi, Bluetooth, OTG, GPS(Gold) (Color : Rose Gold)
# $100.0
# [B06Y44FL9J]
# LINDY 36920 0.5m DisplayPort to HDMI 10.2G Cable, Black
# $17.31
# [B01M7U6F8T]
# Adjustable Cell Phone Stand, Lamicall Desk Phone Holder, Cradle, Dock, Compatible with All 4-8'' Phones, Office Accessories, All Android Smartphone - Black
# $12.99
#
# Action: click[B06Y44FL9J]
# Observation:
# [Back to Search]
# [< Prev]
# size [0.5m][1m] (6.56') - rca plugs][3m][5m]
# LINDY 36920 0.5m DisplayPort to HDMI 10.2G Cable, Black
# Price: $17.31
# Rating: N.A.
# [Description]
# [Features]
# [Reviews]
# [Attributes]
# [Buy Now]
#
# Action: click[Back to Search]
# Observation:
# WebShop
# Instruction:
# i'm looking for a mini pc intel core desktop computer which supports with windows 11, and price lower than 740.00 dollars
# [Search]
#
# Action: search[mini pc intel core windows 11]
# Observation:
# [Back to Search]
# Page 1 (Total results: 50)
# [Next >]
# [B0871VQT3Q]
# Computer & Tablet Y12 4G Phone Call Tablet PC, 10.1 inch, 2GB+32GB, Android 7.0 MTK6753 Octa-core up to 1.6GHz, WiFi, Bluetooth, OTG, GPS(Gold) (Color : Rose Gold)
# $100.0
# [B06Y44FL9J]
# LINDY 36920 0.5m DisplayPort to HDMI 10.2G Cable, Black
# $17.31
# [B01M7U6F8T]
# Adjustable Cell Phone Stand, Lamicall Desk Phone Holder, Cradle, Dock, Compatible with All 4-8'' Phones, Office Accessories, All Android Smartphone - Black
# $12.99
#
# Action: search[mini pc intel core windows 11]
# Observation: Invalid action!
#
# Action: search[mini pc intel core windows 11]
# Observation: Invalid action!
#
# Action: click[B01M7U6F8T]
# Observation:
# [Back to Search]
# [< Prev]
# color [black][gray][red][rose gold][silver]
# Adjustable Cell Phone Stand, Lamicall Desk Phone Holder, Cradle, Dock, Compatible with All 4-8'' Phones, Office Accessories, All Android Smartphone - Black
# Price: $12.99
# Rating: N.A.
# [Description]
# [Features]
# [Reviews]
# [Attributes]
# [Buy Now]
#
# Action: click[< Prev]
# Observation:
# [Back to Search]
# Page 1 (Total results: 50)
# [Next >]
# [B0871VQT3Q]
# Computer & Tablet Y12 4G Phone Call Tablet PC, 10.1 inch, 2GB+32GB, Android 7.0 MTK6753 Octa-core up to 1.6GHz, WiFi, Bluetooth, OTG, GPS(Gold) (Color : Rose Gold)
# $100.0
# [B06Y44FL9J]
# LINDY 36920 0.5m DisplayPort to HDMI 10.2G Cable, Black
# $17.31
# [B01M7U6F8T]
# Adjustable Cell Phone Stand, Lamicall Desk Phone Holder, Cradle, Dock, Compatible with All 4-8'' Phones, Office Accessories, All Android Smartphone - Black
# $12.99
#
# Action: click[B0871VQT3Q]
# Observation:
# [Back to Search]
# [< Prev]
# Computer & Tablet Y12 4G Phone Call Tablet PC, 10.1 inch, 2GB+32GB, Android 7.0 MTK6753 Octa-core up to 1.6GHz, WiFi, Bluetooth, OTG, GPS(Gold) (Color : Rose Gold)
# Price: $100.0
# Rating: N.A.
# [Description]
# [Features]
# [Reviews]
# [Attributes]
# [Buy Now]
#
# Action: click[B01M7U6F8T]
# Observation: Invalid action!
#
# Action: click[B0871VQT3Q]
# Observation: Invalid action!
#
# 117 0.24019607843137258 0.058823529411764705 0.0
# -------------
# -----------------
# 117
# Action: reset
# Observation:
# WebShop
# Instruction:
# i'm looking for headphones are color it was wireless charging it was outside of noise cancellation, and price lower than 190.00 dollars
# [Search]
#
# Action: search[wireless charging headphones]
# Observation:
# [Back to Search]
# Page 1 (Total results: 50)
# [Next >]
# [B092W6WNH4]
# GAOMU IPX6 Waterproof Bluetooth Earbuds, True Wireless Earbuds, 20H Cyclic Playtime Headphones with Charging Case and mic for Android, in-Ear Stereo Earphones Headset for Sport Black
# $11.99
# [B09L86RDXS]
# Comfortable Bluetooth Headset, UX-M97 Wireless Headset with Microphone, Wireless Cell Phone Headset with Noise Isolation Mic Charging Base Mute Function for Xiaomi Poco F3 GT with Charging Dock
# $41.95
# [B09KQNH5C6]
#
# Action: click[Back to Search]
# Observation:
# WebShop
# Instruction:
# i want a king size twin bed with storage compartments
# [Search]
#
# Action: click[B08X2FSR21]
# Observation:
# WebShop
# Instruction:
# i want a king size twin bed with storage compartments
# [Search]
#
# Action: click[Description]
# Observation: Invalid action!
#
# Action: click[Features]
# Observation: Invalid action!
#
# Action: click[Reviews]
# Observation: Invalid action!
#
# Action: click[Buy Now]
# Observation: Invalid action!
#
# Action: click[Description]
# Observation: Invalid action!
#
# 493 0.16715436810856657 0.05343511450381679 0.0
# -------------
# -----------------
# 493
# Action: reset
# Observation:
# WebShop
# Instruction:
# i'm looking for cellphone accessories for wireless charging, and price lower than 50.00 dollars
# [Search]
#
# Action: search[wireless charging cellphone accessories]
# Observation:
# [Back to Search]
# Page 1 (Total results: 50)
# [Next >]
# [B07THL8PP1]
# Anker 10W Max Wireless Charger, 2 Pack 313 Wireless Charger (Pad), Qi-Certified Wireless Charging 7.5W for iPhone 12/12 Pro/12 mini/12 Pro Max, 10W for Galaxy S10 S9 S8, S9 Plus (No AC Adapter)
# $25.99
# [B092W6WNH4]
# GAOMU IPX6 Waterproof Bluetooth Earbuds, True Wireless Earbuds, 20H Cyclic Playtime Headphones with Charging Case and mic for Android, in-Ear Stereo Earphones Headset for Sport Black
# $11.99
# [B09L86RDXS]
# Comfortable Bluetooth Headset, UX-M97 Wireless Headset with Microphone, Wireless Cell Phone Headset with Noise Isolation Mic Charging Base Mute Function for Xiaomi Poco F3 GT with Charging Dock
# $41.95
#
# Action: click[B07THL8PP1]
# Observation:
# [Back to Search]
# [< Prev]
# Anker 10W Max Wireless Charger, 2 Pack 313 Wireless Charger (Pad), Qi-Certified Wireless Charging 7.5W for iPhone 12/12 Pro/12 mini/12 Pro Max, 10W for Galaxy S10 S9 S8, S9 Plus (No AC Adapter)
# Price: $25.99
# Rating: N.A.
# [Description]
# [Features]
# [Reviews]
# [Attributes]
# [Buy Now]
#
# Action: click[B07THL8PP1]
# Observation: Invalid action!
#
# Action: click[B07THL8PP1]
# Observation: Invalid action!
#
# Action: click[B07THL8PP1]
# Observation: Invalid action!
#
# Action: click[B07THL8PP1]
# Observation: Invalid action!
#
# Action: click[B07THL8PP1]
# Observation: Invalid action!
#
# Action: click[B07THL8PP1]
# Observation: Invalid action!
#
# Action: click[B07THL8PP1]
# Observation: Invalid action!
#
# Action: click[B07THL8PP1]
# Observation: Invalid action!
#
# Action: click[B07THL8PP1]
# Observation: Invalid action!
#
# Action: click[B07THL8PP1]
# Observation: Invalid action!
#
# Action: click[B07THL8PP1]
# Observation: Invalid action!
#
# Action: click[B07THL8PP1]
# Observation: Invalid action!
#
# 494 0.1667301184433164 0.0532994923857868 0.0
# -------------
# -----------------
# 494
# Action: reset
# Observation:
# WebShop
# Instruction:
# i am looking for light weight a34 color photo background, and price lower than 50.00 dollars
# [Search]
#
# Action: search[a34 color photo background]
# Observation:
# [Back to Search]
# Page 1 (Total results: 50)
# [Next >]
# [B07X9623L4]
# FUERMOR Light Purple Flash Backdrops 5x7ft Background for Wedding Photography Birthday Cake Table Home Decor YouTube Videos Photo Props FUTJ011
# $19.99
# [B07KK7G5YJ]
# Laeacco Steampunk Clock Backdrops 6.5x6.5ft Vinyl Photography Background Shabby Clock Photo Backdrop Old Clock Punk Grunge Culture Adults Brave Boy Portraits Photo Studio Props
# $24.59
# [B07TB37SG5]
# DORCEV 5x4ft Under The Sea World Photography Backdrop Underwater World Theme Birthday Party Summer Holiday Party Background Underwater Coral Nature Reef Sunlight Wallpaper Sea Photo Studio Props
# $15.99
#
# Action: click[B07X9623L4]
# Observation:
# [Back to Search]
# [< Prev]
# size [5x7ft][5x10ft]
# color [black][blue][dark purple][green][light purple][light silver][pink]
# FUERMOR Light Purple Flash Backdrops 5x7ft Background for Wedding Photography Birthday Cake Table Home Decor YouTube Videos Photo Props FUTJ011
# Price: $19.99
# Rating: N.A.
# [Description]
# [Features]
# [Reviews]
# [Attributes]
# [Buy Now]
#
# Action: click[light purple]
# Observation: You have clicked light purple.
#
# Action: click[Buy Now]
# Observation: Your score (min 0.0, max 1.0): 0.3333333333333333
#
# 495 0.16715189873417718 0.053164556962025315 0.0
# -------------
# -----------------
# 495
# Action: reset
# Observation:
# WebShop
# Instruction:
# i need roasted coffee beans that are dairy free and cinnamon bun flavored, and price lower than 50.00 dollars
# [Search]
#
# Action: search[dairy free cinnamon bun flavored coffee beans]
# Observation:
# [Back to Search]
# Page 1 (Total results: 50)
# [Next >]
# [B09RLQR5NP]
# M&M's Peanut Butter Chocolate Fun Size Packs American Candy In A Variety Of Fun Colors Bulk Party Mix Packaged In Resealable Wholesale Pantry Bag 2 Lbs. (32 Oz)
# $29.99
# [B009LHWYO8]
# Pilon Espresso Coffee, 10 Ounce (Pack of 12)
# $53.88
# [B07FYPSNH8]
# OWYN - 100% Vegan Plant-Based Protein Shakes | Cold Brew Coffee, 12 Fl Oz | Dairy-Free, Gluten-Free, Soy-Free, Tree Nut-Free, Egg-Free, Allergy-Free, Vegetarian
# $11.07
#
# Action: search[dairy free cinnamon bun flavored coffee beans]
# Observation: Invalid action!
#
# Action: search[dairy free cinnamon bun flavored coffee beans]
# Observation: Invalid action!
#
# Action: search[dairy free cinnamon bun flavored coffee beans]
# Observation: Invalid action!
#
# Action: search[dairy free cinnamon bun flavored coffee beans]
# Observation: Invalid action!
#
# Action: search[dairy free cinnamon bun flavored coffee beans]
# Observation: Invalid action!
#
# Action: search[dairy free cinnamon bun flavored coffee beans]
# Observation: Invalid action!
#
# Action: search[dairy free cinnamon bun flavored coffee beans]
# Observation: Invalid action!
#
# Action: search[dairy free cinnamon bun flavored coffee beans]
# Observation: Invalid action!
#
# Action: search[dairy free cinnamon bun flavored coffee beans]
# Observation: Invalid action!
#
# Action: search[dairy free cinnamon bun flavored coffee beans]
# Observation: Invalid action!
#
# Action: search[dairy free cinnamon bun flavored coffee beans]
# Observation: Invalid action!
#
# Action: search[dairy free cinnamon bun flavored coffee beans]
# Observation: Invalid action!
#
# Action: search[dairy free cinnamon bun flavored coffee beans]
# Observation: Invalid action!
#
# 496 0.16672979797979795 0.05303030303030303 0.0
# -------------
# -----------------
# 496
# Action: reset
# Observation:
# WebShop
# Instruction:
# i need brown eco friendly nikahoo small storage baskets, and price lower than 40.00 dollars
# [Search]
#
# Action: search[nikahoo small storage baskets brown eco friendly]
# Observation:
# [Back to Search]
# Page 1 (Total results: 50)
# [Next >]
# [B07SXRVKZ2]
# Fab Habitat Seagrass Storage Basket Set - Wicker Pattern Baskets, Strong Handles - Organizer for Blankets, Towels, Pillows, Toys, Laundry, Baby, Kids, Home Décor - Harlem - XL
# $69.0
# [B09BNCFGLY]
# Wrington Storage Platform Bed, Frame Material: Solid Wood, Eco-Friendly Solid Hardwood with Non-Toxic Finish
# $1514.48
# [B09MYFGDY5]
# Orthodontic Elastics, Safe Orthodontic Rubber Band Pet Grooming Eco Friendly for Men Women for Dental Hospital for Home for Dentist
# $24.35
#
# Action: click[B07SXRVKZ2]
# Observation:
# [Back to Search]
# [< Prev]
# size [large][x-large]
# color [blue][harlem][harlem - sunset]
# Fab Habitat Seagrass Storage Basket Set - Wicker Pattern Baskets, Strong Handles - Organizer for Blankets, Towels, Pillows, Toys, Laundry, Baby, Kids, Home Décor - Harlem - XL
# Price: $69.0
# Rating: N.A.
# [Description]
# [Features]
# [Reviews]
# [Attributes]
# [Buy Now]
#
# Action: click[B09BNCFGLY]
# Observation: Invalid action!
#
# Action: click[B09BNCFGLY]
# Observation: Invalid action!
#
# Action: click[B09MYFGDY5]
# Observation: Invalid action!
#
# Action: click[B09MYFGDY5]
# Observation: Invalid action!
#
# Action: click[B07SXRVKZ2]
# Observation: Invalid action!
#
# Action: click[B09BNCFGLY]
# Observation: Invalid action!
#
# Action: click[B09BNCFGLY]
# Observation: Invalid action!
#
# Action: search[nikahoo small storage baskets brown eco friendly]
# Observation: Invalid action!
#
# Action: click[B09MYFGDY5]
# Observation: Invalid action!
#
# Action: click[B09MYFGDY5]
# Observation: Invalid action!
#
# Action: click[B09BNCFGLY]
# Observation: Invalid action!
#
# Action: click[B09MYFGDY5]
# Observation: Invalid action!
#
# 497 0.16630982367758185 0.05289672544080604 0.0
# -------------
# -----------------
# 497
# Action: reset
# Observation:
# WebShop
# Instruction:
# i am looking for ultra hd motion detection surveillance dome camera color black size :6mp wdr 2.8 mm, and price lower than 200.00 dollars
# [Search]
#
# Action: searchp wdr 2.8mm ultra hd motion detection surveillance dome camera color black]
# Observation:
# [Back to Search]
# Page 1 (Total results: 50)
# [Next >]
# [B07X3TZQ27]
# Mini Spy Camera WiFi Wireless Hidden Video Camera 1080P Full HD Small Nanny Cam with Night Vision Motion Activated Indoor Covert Security Cameras Surveillance Cam for Car Home Office iPhone Android
# $100.0
# [B08VH8MZZ6]
# GRABKEN Mini WiFi Alexa Google Wireless Smart Doorbell Camera with Chime, Battery, 19201080P HD, 2-Way Audio, Motion Detection, IP66 and 32GB TF Card
# $55.99
# [B08D8726MN]
# Spy Camera Wireless Hidden JLRKENG Full HD 4K USB Nanny Cam-Suitable for Home and Office Security Cameras-with Motion Detection-Support Android/iOS
# $100.0
#
# Action: click[B08VH8MZZ6]
# Observation:
# [Back to Search]
# [< Prev]
# GRABKEN Mini WiFi Alexa Google Wireless Smart Doorbell Camera with Chime, Battery, 19201080P HD, 2-Way Audio, Motion Detection, IP66 and 32GB TF Card
# Price: $55.99
# Rating: N.A.
# [Description]
# [Features]
# [Reviews]
# [Attributes]
# [Buy Now]
#
# Action: click[Buy Now]
# Observation: Your score (min 0.0, max 1.0): 0.04000000000000001
#
# 498 0.1659924623115578 0.052763819095477386 0.0
# -------------
# -----------------
# 498
# Action: reset
# Observation:
# WebShop
# Instruction:
# i'm looking for a universal remote control with batteries included, and price lower than 30.00 dollars
# [Search]
#
# Action: search[universal remote control with batteries]
# Observation:
# [Back to Search]
# Page 1 (Total results: 50)
# [Next >]
# [B075ZH94L7]
# RCA Universal Palm Size 3Device DVD VCR TV Remote Control RCU403
# $100.0
# [B09H6G6PT9]
# RM-ADU101 RM-ADU138 Replacement Remote Control Commander fit for Sony Home Theater System HBD-TZ140 DAV-TZ135 HBD-TZ130 DAV-TZ130 DAV-TZ140 HBDTZ140 DAVTZ135 HBDTZ130 DAVTZ130 DAVTZ140
# $7.28
# [B08R8K8H6S]
# RMT-AA231U Replacement Remote Control Applicable for Sony 7.2ch Home Theater AV Receiver STR-DH770 STRDH770
# $9.27
#
# Action: click[B09H6G6PT9]
# Observation:
# [Back to Search]
# [< Prev]
# RM-ADU101 RM-ADU138 Replacement Remote Control Commander fit for Sony Home Theater System HBD-TZ140 DAV-TZ135 HBD-TZ130 DAV-TZ130 DAV-TZ140 HBDTZ140 DAVTZ135 HBDTZ130 DAVTZ130 DAVTZ140
# Price: $7.28
# Rating: N.A.
# [Description]
# [Features]
# [Reviews]
# [Attributes]
# [Buy Now]
#
# Action: click[B09H6G6PT9]
# Observation: Invalid action!
#
# Action: click[B09H6G6PT9]
# Observation: Invalid action!
#
# Action: click[B09H6G6PT9]
# Observation: Invalid action!
#
# Action: click[B09H6G6PT9]
# Observation: Invalid action!
#
# Action: click[B09H6G6PT9]
# Observation: Invalid action!
#
# Action: click[B09H6G6PT9]
# Observation: Invalid action!
#
# Action: click[B09H6G6PT9]
# Observation: Invalid action!
#
# Action: click[B09H6G6PT9]
# Observation: Invalid action!
#
# Action: click[B09H6G6PT9]
# Observation: Invalid action!
#
# Action: click[B09H6G6PT9]
# Observation: Invalid action!
#
# Action: click[B09H6G6PT9]
# Observation: Invalid action!
#
# Action: click[B09H6G6PT9]
# Observation: Invalid action!
#
# 499 0.16557644110275688 0.05263157894736842 0.0
# -------------
# -----------------
# 499
# Action: reset
# Observation:
# WebShop
# Instruction:
# i'm looking for 33.81 fl oz non-gmo gluten free monin raspberry syrup, and price lower than 50.00 dollars
# [Search]
#
# Action: search[33.81 fl oz non-gmo gluten free monin raspberry syrup]
# Observation:
# [Back to Search]
# Page 1 (Total results: 50)
# [Next >]
# [B08BPTT8MX]
# Pediasure Grow & Gain with Immune Support, Kids Protein Shake, 27 Vitamins and Minerals, 7g Protein, Helps Kids Catch Up On Growth, Non-GMO, Gluten-Free, Chocolate, 8 Fl Oz, 16 Count
# $100.0
# [B01N37FSYX]
# Delicious & Sons - Organic - Non-GMO - Gluten-free - Italian Basil Pesto Genovese Sauce with Parmigiano Reggiano PDO Cheese (6.70 oz.)
# $14.99
# [B0874Y2KJR]
# Barbican Lemon Flavor Malt Beverage " Non Alcoholic " Drink - Pack of 6 Glass Bottles 330ML !
# $29.99
#
# Action: search[monin raspberry syrup 33.81 fl oz non gmo gluten free]
# Observation: Invalid action!
#
# Action: search[monin raspberry syrup 33.81 fl oz non gmo gluten free]
# Observation: Invalid action!
#
# Action: search[monin raspberry syrup 33.81 fl oz non gmo gluten free]
# Observation: Invalid action!
#
# Action: search[monin raspberry syrup 33.81 fl oz non gmo gluten free]
# Observation: Invalid action!
#
# Action: search[monin raspberry syrup 33.81 fl oz non gmo gluten free]
# Observation: Invalid action!
#
# Action: search[monin raspberry syrup 33.81 fl oz non gmo gluten free]
# Observation: Invalid action!
#
# Action: search[monin raspberry syrup 33.81 fl oz non gmo gluten free]
# Observation: Invalid action!
#
# Action: search[monin raspberry syrup 33.81 fl oz non gmo gluten free]
# Observation: Invalid action!
#
# Action: search[monin raspberry syrup 33.81 fl oz non gmo gluten free]
# Observation: Invalid action!
#
# Action: search[monin raspberry syrup 33.81 fl oz non gmo gluten free]
# Observation: Invalid action!
#
# Action: search[monin raspberry syrup 33.81 fl oz non gmo gluten free]
# Observation: Invalid action!
#
# Action: search[monin raspberry syrup 33.81 fl oz non gmo gluten free]
# Observation: Invalid action!
#
# Action: search[monin raspberry syrup 33.81 fl oz non gmo gluten free]
# Observation: Invalid action!
#
# 500 0.1651625 0.0525 0.0
# -------------
# 0.1651625 0.042 0.0

# %%
# fx = 50 
# webshop_run(f'fixed_{fx}', prompt1, to_print=True)
