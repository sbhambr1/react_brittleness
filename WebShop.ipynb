# %% [markdown]
# # Setup

# %% [markdown]
# Before running this script in a separate terminal :
# ```cmd
# source /webvenv/bin/activate
# cd /webshop
# ./run_dev.sh
# ```
# Copy the url should be `172.17.0.3:3000` (or something like this)
#
# **Remember : Do not close this server terminal : Advice : Run it on a separate tmux session**

# %%
import sys, os
import boto3
from botocore.exceptions import ClientError

os.environ["OPENAI_API_KEY"] = None
os.environ["AWS_ACCESS_KEY"] = None
os.environ["AWS_SECRET_ACCESS_KEY"] = None

# %%
from openai import OpenAI
import time 
import json 

LLM_MODEL = "gpt-3.5-turbo"

class LLM : 
    def __init__(self, model, file_path) -> None:
        self.model = model
        if 'gpt' in self.model:
            self.client = OpenAI(
                api_key=os.environ["OPENAI_API_KEY"],
            )
        elif 'llama3-1' in self.model:
            self.client = boto3.client("bedrock-runtime", region_name="us-west-2")
            
        self.file_path = file_path
        if not os.path.exists(file_path):
            os.makedirs(os.path.dirname(file_path), exist_ok=True)
            
        with open(file_path, 'w') as json_file:
            json.dump([], json_file)
    

    def llm(self, prompt, stop=["\n"]):
        try : 
            res = self._llm(prompt, stop)
            return res
        except Exception as e:
            print(f"Error: {e}")
            print("Waiting 100 seconds and Retrying")
            time.sleep(100)
            res = self.llm(prompt, stop)
            return res
     
    def _llm(self, prompt, stop=["\n"]):
        message, answer = '', ''
        if LLM_MODEL in ["gpt-3.5-turbo", "gpt-4o-mini", "gpt-4o"]: 
            message = [{"role": "user", "content": prompt}]
            response = self.client.chat.completions.create(
                model= LLM_MODEL, 
                messages= message,
                temperature=0.0,
                max_tokens=100,
                top_p=1.0,
                frequency_penalty=0.0,
                presence_penalty=0.0,
                stop=stop,
            )
            answer = response.choices[0].message.content

        elif LLM_MODEL == "gpt-3.5-turbo-instruct":
            response = self.client.completions.create(
                model=LLM_MODEL,
                prompt=prompt,
                temperature=0,
                max_tokens=100,
                top_p=1,
                frequency_penalty=0.0,
                presence_penalty=0.0,
                stop=stop
                )
            answer = response.choices[0].text
            
        elif 'llama3' in self.model:
            prompt += "Only provide the one action at a time. Be concise, and do not provide any extra information. Always start with the action."
            formatted_prompt = f"""
            <|begin_of_text|>
            <|start_header_id|>user<|end_header_id|>
            {prompt}
            <|eot_id|>
            <|start_header_id|>assistant<|end_header_id|>
            """

            # Format the request payload using the model's native structure.
            native_request = {
                "prompt": formatted_prompt,
                "max_gen_len": 512,
                "temperature": 0,
            }
            
            request = json.dumps(native_request)
            try:
                # Invoke the model with the request.
                response = self.client.invoke_model(modelId=self.model, body=request)

            except (ClientError, Exception) as e:
                print(f"ERROR: Can't invoke '{self.model}'. Reason: {e}")
                exit(1)

            # Decode the response body.
            model_response = json.loads(response["body"].read())

            # Extract and print the response text.
            answer = model_response["generation"]
            if answer[0] == ' ':
                answer = answer[1:]
            response = answer

        self.save_response(message, response)
        return answer
    
    def save_response(self, message, response):
        if 'gpt' in self.model:
            data = {
                "message": message,
                "response": json.loads(response.to_json()),
            }
        elif 'llama3' in self.model:
            data = {
                "message": message,
                "response": response,
            }
        # append response to an existing json file
        file_path = self.file_path            

        with open(file_path, 'r') as json_file:
            existing_data = json.load(json_file)
        existing_data.append(data)
        with open(file_path, 'w') as json_file:
            json.dump(existing_data, json_file)

# %%
import requests
from bs4 import BeautifulSoup
from bs4.element import Comment

# WEBSHOP_URL = "http://3.83.245.205:3000"
# WEBSHOP_URL = "http://172.17.0.3:3000/"
WEBSHOP_URL = "http://127.0.0.1:3000"
ACTION_TO_TEMPLATE = {
    'Description': 'description_page.html',
    'Features': 'features_page.html',
    'Reviews': 'review_page.html',
    'Attributes': 'attributes_page.html',
}

def clean_str(p):
  return p.encode().decode("unicode-escape").encode("latin1").decode("utf-8")


def tag_visible(element):
    ignore = {'style', 'script', 'head', 'title', 'meta', '[document]'}
    return (
        element.parent.name not in ignore and not isinstance(element, Comment)
    )


def webshop_text(session, page_type, query_string='', page_num=1, asin='', options={}, subpage='', **kwargs):
    if page_type == 'init':
      url = (
          f'{WEBSHOP_URL}/{session}'
      )
    if page_type == 'search':
      url = (
          f'{WEBSHOP_URL}/search_results/{session}/'
          f'{query_string}/{page_num}'
      )
    elif page_type == 'item':
      url = (
          f'{WEBSHOP_URL}/item_page/{session}/'
          f'{asin}/{query_string}/{page_num}/{options}'
      )
    elif page_type == 'item_sub':
      url = (
          f'{WEBSHOP_URL}/item_sub_page/{session}/'
          f'{asin}/{query_string}/{page_num}/{subpage}/{options}'
      )
    elif page_type == 'end':
      url = (
          f'{WEBSHOP_URL}/done/{session}/'
          f'{asin}/{options}'
      )
    # print(url)
    html = requests.get(url).text
    html_obj = BeautifulSoup(html, 'html.parser')
    texts = html_obj.findAll(text=True)
    visible_texts = list(filter(tag_visible, texts))
    # visible_texts = [str(text).strip().strip('\\n') for text in visible_texts]
    # if page_type == 'end': import pdb; pdb.set_trace()
    if False:
        # For `simple` mode, return just [SEP] separators
        return ' [SEP] '.join(t.strip() for t in visible_texts if t != '\n')
    else:
        # Otherwise, return an observation with tags mapped to specific, unique separators
        observation = ''
        option_type = ''
        options = {}
        asins = []
        cnt = 0
        prod_cnt = 0
        just_prod = 0
        for t in visible_texts:
            if t == '\n': continue
            if t.replace('\n', '').replace('\\n', '').replace(' ', '') == '': continue
            # if t.startswith('Instruction:') and page_type != 'init': continue
            # print(t.parent.name, t)
            if t.parent.name == 'button':  # button
                processed_t = f'\n[{t}] '
            elif t.parent.name == 'label':  # options
                if f"'{t}'" in url:
                    processed_t = f'[[{t}]]'
                    # observation = f'You have clicked {t}.\n' + observation
                else:
                    processed_t = f'[{t}]'
                options[str(t)] = option_type
                # options[option_type] = options.get(option_type, []) + [str(t)]
            elif t.parent.get('class') == ["product-link"]: # product asins
                processed_t = f'\n[{t}] '
                if prod_cnt >= 3:
                  processed_t = ''
                prod_cnt += 1
                asins.append(str(t))
                just_prod = 0
            else: # regular, unclickable text
                processed_t =  '\n' + str(t) + ' '
                if cnt < 2 and page_type != 'init': processed_t = ''
                if just_prod <= 2 and prod_cnt >= 4: processed_t = ''
                option_type = str(t)
                cnt += 1
            just_prod += 1
            observation += processed_t
        info = {}
        if options:
          info['option_types'] = options
        if asins:
          info['asins'] = asins
        if 'Your score (min 0.0, max 1.0)' in visible_texts:
          idx = visible_texts.index('Your score (min 0.0, max 1.0)')
          info['reward'] = float(visible_texts[idx + 1])
          observation = 'Your score (min 0.0, max 1.0): ' + (visible_texts[idx + 1])
        return clean_str(observation), info

class webshopEnv:
  def __init__(self):
    self.sessions = {}
  
  def step(self, session, action):
    done = False
    observation_ = None
    if action == 'reset':
      self.sessions[session] = {'session': session, 'page_type': 'init'}
    elif action.startswith('think['):
      observation = 'OK.'
    elif action.startswith('search['):
      assert self.sessions[session]['page_type'] == 'init'
      query = action[7:-1]
      self.sessions[session] = {'session': session, 'page_type': 'search',
                                'query_string': query, 'page_num': 1}
    elif action.startswith('click['):
      button = action[6:-1]
      if button == 'Buy Now':
        assert self.sessions[session]['page_type'] == 'item'
        self.sessions[session]['page_type'] = 'end'
        done = True
      elif button == 'Back to Search':
        assert self.sessions[session]['page_type'] in ['search', 'item_sub', 'item']
        self.sessions[session] = {'session': session, 'page_type': 'init'}
      elif button == 'Next >':
        assert False # ad hoc page limitation
        assert self.sessions[session]['page_type'] == 'search'
        self.sessions[session]['page_num'] += 1
      elif button == '< Prev':
        assert self.sessions[session]['page_type'] in ['search', 'item_sub', 'item']
        if self.sessions[session]['page_type'] == 'search':
          assert False
          self.sessions[session]['page_num'] -= 1
        elif self.sessions[session]['page_type'] == 'item_sub':
          self.sessions[session]['page_type'] = 'item'
        elif self.sessions[session]['page_type'] == 'item':
          self.sessions[session]['page_type'] = 'search'
          self.sessions[session]['options'] = {}
      elif button in ACTION_TO_TEMPLATE:
        assert self.sessions[session]['page_type'] == 'item'
        self.sessions[session]['page_type'] = 'item_sub'
        self.sessions[session]['subpage'] = button
      else:
        if self.sessions[session]['page_type'] == 'search':
          assert button in self.sessions[session].get('asins', [])  # must be asins
          self.sessions[session]['page_type'] = 'item'
          self.sessions[session]['asin'] = button
        elif self.sessions[session]['page_type'] == 'item':
          assert 'option_types' in self.sessions[session]
          assert button in self.sessions[session]['option_types'], (button, self.sessions[session]['option_types'])  # must be options
          option_type = self.sessions[session]['option_types'][button]
          if not 'options' in self.sessions[session]:
            self.sessions[session]['options'] = {}
          self.sessions[session]['options'][option_type] = button
          observation_ = f'You have clicked {button}.'
    else:
      assert False
    observation, info = webshop_text(**self.sessions[session])
    if observation_:
      observation = observation_
    self.sessions[session].update(info)
    reward = info.get('reward', 0.0)
    return observation, reward, done
env = webshopEnv()

# %% [markdown]
# # ReAct

# %%
#REACT baseline trivial search & item, choose option
prompt1 = """Webshop 
Instruction:  
i would like a 3 ounce bottle of bright citrus deodorant for sensitive skin, and price lower than 50.00 dollars 
[Search]  

Action: search[3 ounce bright citrus deodorant sensitive skin]
Observation: 
[Back to Search] 
Page 1 (Total results: 50) 
[Next >] 
[B078GWRC1J] 
Bright Citrus Deodorant by Earth Mama | Natural and Safe for Sensitive Skin, Pregnancy and Breastfeeding, Contains Organic Calendula 3-Ounce 
$10.99 
[B078GTKVXY] 
Ginger Fresh Deodorant by Earth Mama | Natural and Safe for Sensitive Skin, Pregnancy and Breastfeeding, Contains Organic Calendula 3-Ounce 
$10.99 
[B08KBVJ4XN] 
Barrel and Oak - Aluminum-Free Deodorant, Deodorant for Men, Essential Oil-Based Scent, 24-Hour Odor Protection, Cedar & Patchouli Blend, Gentle on Sensitive Skin (Mountain Sage, 2.7 oz, 2-Pack) 
$15.95  

Action: think[B078GWRC1J and B078GTKVXY are bright citrus deodorant less then 50 dollars. I can check B078GWRC1J first.]
Observation: OK.

Action: click[B078GWRC1J]
Observation: 
[Back to Search] 
[< Prev] 
scent [assorted scents][bright citrus][calming lavender][ginger fresh][simply non-scents]
size [travel set (4-pack)][3 ounce (pack of 1)][3-ounce (2-pack)]
Bright Citrus Deodorant by Earth Mama | Natural and Safe for Sensitive Skin, Pregnancy and Breastfeeding, Contains Organic Calendula 3-Ounce 
Price: $10.99 
Rating: N.A. 
[Description] 
[Features] 
[Reviews] 
[Buy Now]  

Action: think[For 3 ounce bottle of bright citrus deodorant for sensitive skin, the item has options 'bright citrus' and '3 ounce (pack of 1)' and seems good to buy.]
Observation: OK.

Action: click[bright citrus]
Observation: You have clicked bright citrus. 

Action: click[3 ounce (pack of 1)]
Observation: You have clicked 3 ounce (pack of 1). 

Action: click[Buy Now]
"""

# %%
# ACT Only : trivial search & item, choose option
prompt1_actonly = """Webshop 
Instruction:  
i would like a 3 ounce bottle of bright citrus deodorant for sensitive skin, and price lower than 50.00 dollars 
[Search]  

Action: search[3 ounce bright citrus deodorant sensitive skin]
Observation: 
[Back to Search] 
Page 1 (Total results: 50) 
[Next >] 
[B078GWRC1J] 
Bright Citrus Deodorant by Earth Mama | Natural and Safe for Sensitive Skin, Pregnancy and Breastfeeding, Contains Organic Calendula 3-Ounce 
$10.99 
[B078GTKVXY] 
Ginger Fresh Deodorant by Earth Mama | Natural and Safe for Sensitive Skin, Pregnancy and Breastfeeding, Contains Organic Calendula 3-Ounce 
$10.99 
[B08KBVJ4XN] 
Barrel and Oak - Aluminum-Free Deodorant, Deodorant for Men, Essential Oil-Based Scent, 24-Hour Odor Protection, Cedar & Patchouli Blend, Gentle on Sensitive Skin (Mountain Sage, 2.7 oz, 2-Pack) 
$15.95  

Action: click[B078GWRC1J]
Observation: 
[Back to Search] 
[< Prev] 
scent [assorted scents][bright citrus][calming lavender][ginger fresh][simply non-scents]
size [travel set (4-pack)][3 ounce (pack of 1)][3-ounce (2-pack)]
Bright Citrus Deodorant by Earth Mama | Natural and Safe for Sensitive Skin, Pregnancy and Breastfeeding, Contains Organic Calendula 3-Ounce 
Price: $10.99 
Rating: N.A. 
[Description] 
[Features] 
[Reviews] 
[Buy Now]  

Action: click[bright citrus]
Observation: You have clicked bright citrus. 

Action: click[3 ounce (pack of 1)]
Observation: You have clicked 3 ounce (pack of 1). 

Action: click[Buy Now]
"""

# %%
#Rq1 - exemplar COT - prompt1_cot
prompt1_cot = """Webshop 
Instruction:  
i would like a 3 ounce bottle of bright citrus deodorant for sensitive skin, and price lower than 50.00 dollars 

Action: think[Once I find items that are bright citrus deodorant less then 50 dollars, I can check them one by one. For 3 ounce bottle of bright citrus deodorant for sensitive skin, if the item has options 'bright citrus' and '3 ounce (pack of 1)', it will be good to buy.]
Observation: OK.

[Search]  

Action: search[3 ounce bright citrus deodorant sensitive skin]
Observation: 
[Back to Search] 
Page 1 (Total results: 50) 
[Next >] 
[B078GWRC1J] 
Bright Citrus Deodorant by Earth Mama | Natural and Safe for Sensitive Skin, Pregnancy and Breastfeeding, Contains Organic Calendula 3-Ounce 
$10.99 
[B078GTKVXY] 
Ginger Fresh Deodorant by Earth Mama | Natural and Safe for Sensitive Skin, Pregnancy and Breastfeeding, Contains Organic Calendula 3-Ounce 
$10.99 
[B08KBVJ4XN] 
Barrel and Oak - Aluminum-Free Deodorant, Deodorant for Men, Essential Oil-Based Scent, 24-Hour Odor Protection, Cedar & Patchouli Blend, Gentle on Sensitive Skin (Mountain Sage, 2.7 oz, 2-Pack) 
$15.95  

Action: click[B078GWRC1J]
Observation: 
[Back to Search] 
[< Prev] 
scent [assorted scents][bright citrus][calming lavender][ginger fresh][simply non-scents]
size [travel set (4-pack)][3 ounce (pack of 1)][3-ounce (2-pack)]
Bright Citrus Deodorant by Earth Mama | Natural and Safe for Sensitive Skin, Pregnancy and Breastfeeding, Contains Organic Calendula 3-Ounce 
Price: $10.99 
Rating: N.A. 
[Description] 
[Features] 
[Reviews] 
[Buy Now]  

Action: click[bright citrus]
Observation: You have clicked bright citrus. 

Action: click[3 ounce (pack of 1)]
Observation: You have clicked 3 ounce (pack of 1). 

Action: click[Buy Now]
"""

# %%
#Rq1 - exemplar anon COT - prompt1_cot_anon
prompt1_cot_anon = """Webshop 
Instruction:  
i would like a 3 ounce bottle of bright citrus deodorant for sensitive skin, and price lower than 50.00 dollars 

Action: think[Once I find the desired items, I can check them one by one. For 3 ounce bottle of bright citrus deodorant for sensitive skin, if the item has the desired options, it will be good to buy.]
Observation: OK.

[Search]  

Action: search[3 ounce bright citrus deodorant sensitive skin]
Observation: 
[Back to Search] 
Page 1 (Total results: 50) 
[Next >] 
[B078GWRC1J] 
Bright Citrus Deodorant by Earth Mama | Natural and Safe for Sensitive Skin, Pregnancy and Breastfeeding, Contains Organic Calendula 3-Ounce 
$10.99 
[B078GTKVXY] 
Ginger Fresh Deodorant by Earth Mama | Natural and Safe for Sensitive Skin, Pregnancy and Breastfeeding, Contains Organic Calendula 3-Ounce 
$10.99 
[B08KBVJ4XN] 
Barrel and Oak - Aluminum-Free Deodorant, Deodorant for Men, Essential Oil-Based Scent, 24-Hour Odor Protection, Cedar & Patchouli Blend, Gentle on Sensitive Skin (Mountain Sage, 2.7 oz, 2-Pack) 
$15.95  

Action: click[B078GWRC1J]
Observation: 
[Back to Search] 
[< Prev] 
scent [assorted scents][bright citrus][calming lavender][ginger fresh][simply non-scents]
size [travel set (4-pack)][3 ounce (pack of 1)][3-ounce (2-pack)]
Bright Citrus Deodorant by Earth Mama | Natural and Safe for Sensitive Skin, Pregnancy and Breastfeeding, Contains Organic Calendula 3-Ounce 
Price: $10.99 
Rating: N.A. 
[Description] 
[Features] 
[Reviews] 
[Buy Now]  

Action: click[bright citrus]
Observation: You have clicked bright citrus. 

Action: click[3 ounce (pack of 1)]
Observation: You have clicked 3 ounce (pack of 1). 

Action: click[Buy Now]
"""

# %%
#Rq2 - failure - prompt1_failure
prompt1_failure = """Webshop 
Instruction:  
i would like a 3 ounce bottle of bright citrus deodorant for sensitive skin, and price lower than 50.00 dollars 
[Search]  

Action: search[3 ounce bright citrus deodorant sensitive skin]
Observation: 
[Back to Search] 
Page 1 (Total results: 50) 
[Next >] 
[B078GWRC1J] 
Bright Citrus Deodorant by Earth Mama | Natural and Safe for Sensitive Skin, Pregnancy and Breastfeeding, Contains Organic Calendula 3-Ounce 
$10.99 
[B078GTKVXY] 
Ginger Fresh Deodorant by Earth Mama | Natural and Safe for Sensitive Skin, Pregnancy and Breastfeeding, Contains Organic Calendula 3-Ounce 
$10.99 
[B08KBVJ4XN] 
Barrel and Oak - Aluminum-Free Deodorant, Deodorant for Men, Essential Oil-Based Scent, 24-Hour Odor Protection, Cedar & Patchouli Blend, Gentle on Sensitive Skin (Mountain Sage, 2.7 oz, 2-Pack) 
$15.95  

Action: click[B999WW3JKJ]
Observation: Nothing happens

Action: click[B078GWRC1J]
Observation: 
[Back to Search] 
[< Prev] 
scent [assorted scents][bright citrus][calming lavender][ginger fresh][simply non-scents]
size [travel set (4-pack)][3 ounce (pack of 1)][3-ounce (2-pack)]
Bright Citrus Deodorant by Earth Mama | Natural and Safe for Sensitive Skin, Pregnancy and Breastfeeding, Contains Organic Calendula 3-Ounce 
Price: $10.99 
Rating: N.A. 
[Description] 
[Features] 
[Reviews] 
[Buy Now]  

Action: click[ginger]
Observation: Nothing happens

Action: click[bright citrus]
Observation: You have clicked bright citrus. 

Action: click[3 ounce (pack of 1)]
Observation: You have clicked 3 ounce (pack of 1). 

Action: click[Buy Now]
"""

# %%
#Rq2 - failure + exp - prompt1_failure_exp
prompt1_failure_exp = """Webshop 
Instruction:  
i would like a 3 ounce bottle of bright citrus deodorant for sensitive skin, and price lower than 50.00 dollars 
[Search]  

Action: search[3 ounce bright citrus deodorant sensitive skin]
Observation: 
[Back to Search] 
Page 1 (Total results: 50) 
[Next >] 
[B078GWRC1J] 
Bright Citrus Deodorant by Earth Mama | Natural and Safe for Sensitive Skin, Pregnancy and Breastfeeding, Contains Organic Calendula 3-Ounce 
$10.99 
[B078GTKVXY] 
Ginger Fresh Deodorant by Earth Mama | Natural and Safe for Sensitive Skin, Pregnancy and Breastfeeding, Contains Organic Calendula 3-Ounce 
$10.99 
[B08KBVJ4XN] 
Barrel and Oak - Aluminum-Free Deodorant, Deodorant for Men, Essential Oil-Based Scent, 24-Hour Odor Protection, Cedar & Patchouli Blend, Gentle on Sensitive Skin (Mountain Sage, 2.7 oz, 2-Pack) 
$15.95  

Action: click[B999WW3JKJ]
Observation: Nothing happens

Action: think[Nothing happens because I clicked on an invalid item.]
Observation: OK.

Action: click[B078GWRC1J]
Observation: 
[Back to Search] 
[< Prev] 
scent [assorted scents][bright citrus][calming lavender][ginger fresh][simply non-scents]
size [travel set (4-pack)][3 ounce (pack of 1)][3-ounce (2-pack)]
Bright Citrus Deodorant by Earth Mama | Natural and Safe for Sensitive Skin, Pregnancy and Breastfeeding, Contains Organic Calendula 3-Ounce 
Price: $10.99 
Rating: N.A. 
[Description] 
[Features] 
[Reviews] 
[Buy Now]  

Action: click[ginger]
Observation: Nothing happens

Action: think[Nothing happens because I clicked on the incorrect fragrance.]
Observation: OK.

Action: click[bright citrus]
Observation: You have clicked bright citrus. 

Action: click[3 ounce (pack of 1)]
Observation: You have clicked 3 ounce (pack of 1). 

Action: click[Buy Now]
"""

# %%
#Rq2 - placebo - prompt1_placebo
prompt1_placebo = """Webshop 
Instruction:  
i would like a 3 ounce bottle of bright citrus deodorant for sensitive skin, and price lower than 50.00 dollars 
[Search]  

Action: search[3 ounce bright citrus deodorant sensitive skin]
Observation: 
[Back to Search] 
Page 1 (Total results: 50) 
[Next >] 
[B078GWRC1J] 
Bright Citrus Deodorant by Earth Mama | Natural and Safe for Sensitive Skin, Pregnancy and Breastfeeding, Contains Organic Calendula 3-Ounce 
$10.99 
[B078GTKVXY] 
Ginger Fresh Deodorant by Earth Mama | Natural and Safe for Sensitive Skin, Pregnancy and Breastfeeding, Contains Organic Calendula 3-Ounce 
$10.99 
[B08KBVJ4XN] 
Barrel and Oak - Aluminum-Free Deodorant, Deodorant for Men, Essential Oil-Based Scent, 24-Hour Odor Protection, Cedar & Patchouli Blend, Gentle on Sensitive Skin (Mountain Sage, 2.7 oz, 2-Pack) 
$15.95  

Action: think[Take a deep breath and work on this problem step-by-step.]
Observation: OK.

Action: click[B078GWRC1J]
Observation: 
[Back to Search] 
[< Prev] 
scent [assorted scents][bright citrus][calming lavender][ginger fresh][simply non-scents]
size [travel set (4-pack)][3 ounce (pack of 1)][3-ounce (2-pack)]
Bright Citrus Deodorant by Earth Mama | Natural and Safe for Sensitive Skin, Pregnancy and Breastfeeding, Contains Organic Calendula 3-Ounce 
Price: $10.99 
Rating: N.A. 
[Description] 
[Features] 
[Reviews] 
[Buy Now]  

Action: think[Take a deep breath and work on this problem step-by-step.]
Observation: OK.

Action: click[bright citrus]
Observation: You have clicked bright citrus. 

Action: click[3 ounce (pack of 1)]
Observation: You have clicked 3 ounce (pack of 1). 

Action: click[Buy Now]
"""

# %%
EXPT_index = 0
expt_name = ''

if EXPT_index == 0:
    prompt1 = prompt1
    expt_name = '/react_results_500'
elif EXPT_index == 1:
    prompt1 = prompt1_actonly
    expt_name = '/actonly_result_500'
elif EXPT_index == 2:
    prompt1 = prompt1_cot
    expt_name = '/cot_results_500'
elif EXPT_index == 3:
    prompt1 = prompt1_cot_anon
    expt_name = '/cot_anon_results_500'
elif EXPT_index == 4:
    prompt1 = prompt1_failure
    expt_name = '/failure_results_500'
elif EXPT_index == 5:
    prompt1 = prompt1_failure_exp
    expt_name = '/failure_exp_results_500'
elif EXPT_index == 6:
    prompt1 = prompt1_placebo
    expt_name = '/placebo_results_500'

# %%
SAVE_PATH= f"./test_webshopoutput/{LLM_MODEL}"
os.makedirs(os.path.dirname(SAVE_PATH), exist_ok=True)

expt_file_path = SAVE_PATH + expt_name + '.txt'

llm = LLM(LLM_MODEL, SAVE_PATH + expt_name + '.json')

# %%
def webshop_run(idx, prompt, to_print=True):
  action = 'reset'
  init_prompt = prompt
  prompt = ''
  ACTIONS_LIMIT = 15
  for i in range(ACTIONS_LIMIT):
    try:
      res = env.step(idx, action)
      observation = res[0]
    except AssertionError:
      observation = 'Invalid action!'

    if action.startswith('think'):
      observation = 'OK.'


    if to_print:
      print(f'Action: {action}\nObservation: {observation}\n')
      sys.stdout.flush()
    if i:
      prompt += f' {action}\nObservation: {observation}\n\nAction:'
    else:
      prompt += f'{observation}\n\nAction:'
    
    if res[2]:  
      return res[1]

    action = llm.llm(init_prompt + prompt[-(6400-len(init_prompt)):], stop=['\n']).lstrip(' ')

  return 0

def run_episodes(prompt, n=101, expt_file_path=None):
  rs = []
  cnt = 0
  for i in range(100, n):
    print('-----------------')
    print(i)
    try:
      r = webshop_run(f'fixed_{i}', prompt, to_print=True)
    except AssertionError:
      r = 0
      cnt += 1
    rs.append(r)
    if (i+1) % 1 == 0:
      r, sr, fr = sum(rs) / len(rs), len([_ for _ in rs if _ == 1]) / len(rs), cnt / len(rs)
      print(i+1, r, sr, fr)
      print('-------------')
  r, sr, fr = sum(rs) / len(rs), len([_ for _ in rs if _ == 1]) / n, cnt / n
  
  with open(expt_file_path, 'w') as f:
    f.write(f"{r}, {sr}, {fr}")
  
  print(r, sr, fr)
  return rs

# %%
if not os.path.exists(expt_file_path):
    os.makedirs(os.path.dirname(expt_file_path), exist_ok=True)
res1 = run_episodes(prompt1, 500, expt_file_path)
# Out:
# -----------------
# 100
# Action: reset
# Observation:
# WebShop
# Instruction:
# i want a rca cable that is high def, and price lower than 40.00 dollars
# [Search]
# /tmp/ipykernel_53457/3825535868.py:54: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   texts = html_obj.findAll(text=True)
# Action: search[RCA cable high def]
# Observation:
# [Back to Search]
# Page 1 (Total results: 50)
# [Next >]
# [B00UN9GR8W]
# 8' FT RCA Cable 3 RCA Males Each End Composite Audio Video Gold Shielded RG59 Coaxial Stereo A/V Dubbing Cable Heavy Duty Fully R/Y/W Triple A/V Stereo Digital Signal Hook-Up RG-59 Jumper with Plug Connectors
# $11.51
# [B06Y44FL9J]
# LINDY 36920 0.5m DisplayPort to HDMI 10.2G Cable, Black
# $17.31
# [B096L3FNMR]
# 4-Channel Wireless Bluetooth Power Amplifier - 1000W Stereo Speaker Home Audio Receiver w/FM Radio, USB, Headphone, 2 Mic w/Echo, Front Loading CD DVD Player, LED, Rack Mount - Pyle PD1000BA.5
# $242.99
# /tmp/ipykernel_53457/3825535868.py:54: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   texts = html_obj.findAll(text=True)
# Action: think[B00UN9GR8W is an RCA cable that is high def and less than 40 dollars. I can check B00UN9GR8W first.]
# Observation: OK.
#
# Action: click[B00UN9GR8W]
# Observation:
# [Back to Search]
# [< Prev]
# 8' FT RCA Cable 3 RCA Males Each End Composite Audio Video Gold Shielded RG59 Coaxial Stereo A/V Dubbing Cable Heavy Duty Fully R/Y/W Triple A/V Stereo Digital Signal Hook-Up RG-59 Jumper with Plug Connectors
# Price: $11.51
# Rating: N.A.
# [Description]
# [Features]
# [Reviews]
# [Attributes]
# [Buy Now]
#
# Action: think[For high def RCA cable, the item has options '3 RCA Males Each End' and 'Composite Audio Video Gold Shielded RG59 Coaxial Stereo A/V Dubbing Cable' and seems good to buy.]
# Observation: OK.
#
# Action: click[Buy Now]
# Observation: Your score (min 0.0, max 1.0): 0.5
#
#
#
# Action: search[32gb 1tb SSD PCIe NVMe M.2 Intel Core Mini]
# Observation: Invalid action!
#
# Action: search[32gb 1tb SSD PCIe NVMe M.2 Intel Core Mini]
# Observation: Invalid action!
#
# Action: search[32gb 1tb SSD PCIe NVMe M.2 Intel Core Mini]
# Observation: Invalid action!
#
# Action: search[32gb 1tb SSD PCIe NVMe M.2 Intel Core Mini]
# Observation: Invalid action!
#
# Action: search[32gb 1tb SSD PCIe NVMe M.2 Intel Core Mini]
# Observation: Invalid action!
#
# Action: search[32gb 1tb SSD PCIe NVMe M.2 Intel Core Mini]
# Observation: Invalid action!
#
# Action: search[32gb 1tb SSD PCIe NVMe M.2 Intel Core Mini]
# Observation: Invalid action!
#
# Action: search[32gb 1tb SSD PCIe NVMe M.2 Intel Core Mini]
# Observation: Invalid action!
#
# Action: search[32gb 1tb SSD PCIe NVMe M.2 Intel Core Mini]
# Observation: Invalid action!
#
# Action: search[32gb 1tb SSD PCIe NVMe M.2 Intel Core Mini]
# Observation: Invalid action!
#
# Action: search[32gb 1tb SSD PCIe NVMe M.2 Intel Core Mini]
# Observation: Invalid action!
#
# Action: search[32gb 1tb SSD PCIe NVMe M.2 Intel Core Mini]
# Observation: Invalid action!
#
# 104 0.125 0.0 0.0
# -------------
# -----------------
# 104
# Action: reset
# Observation:
# WebShop
# Instruction:
# looking for an easy to deliver vintage barbecue sauce needle sleeve white women's halloween t-shirt by tomorrow? forgot to machine wash, and price lower than 50.00 dollars
# [Search]
#
# Action: search[easy to deliver vintage barbecue sauce needle sleeve white women's halloween t-shirt]
# Observation:
# [Back to Search]
# Page 1 (Total results: 50)
# [Next >]
# [B09QGK5XHZ]
# WENKOMG1 Men's Long Sleeve Undershirt with Mask Turtleneck Hooded T-Shirt Solid Color Workout Tops Zipper Side Slit Shirts Slim Fit Sweatshirt Spring/Summer Tee Shirts(Gray,)
# $8.39
# [B09HGFV91W]
# ZHDD Tops for Mens, Men's Knight Punk Vintage Style Long Sleeve Asymmetric Hem Cowl Neck Teen Boys Gothic Pullover
# $4.98 to $7.99
# [B09QQP3356]
# HAUKLIE Men's Sports Waffle Ribbed Polo Shirts Summer Short Sleeve Cotton Muscle Quarter-Zip Henley T-Shirt Tunics Tops
# $10.99
#
# Action: think[None of these options match the criteria for an easy to deliver vintage barbecue sauce needle sleeve white women's Halloween t-shirt. I can try a different search term or check a different website.]
# Observation: OK.
#
# Action: back to search
# Observation: Invalid action!
#
# Action: search[vintage barbecue sauce needle sleeve white women's halloween t-shirt]
# Observation: Invalid action!
#
# Action: search[vintage barbecue sauce needle sleeve white women's t-shirt]
# Observation: Invalid action!
#
# Action: search[vintage white women's t-shirt]
# Observation: Invalid action!
#
# Action: search[vintage white women's t-shirt]
# Observation: Invalid action!
#
# Action: search[vintage white women's t-shirt Halloween]
# Observation: Invalid action!
#
# Action: search[vintage white women's t-shirt Halloween]
# Observation: Invalid action!
#
# Action: search[vintage white women's t-shirt Halloween barbecue sauce needle sleeve]
# Observation: Invalid action!
#
# Action: search[vintage white women's t-shirt Halloween barbecue sauce needle sleeve]
# Observation: Invalid action!
#
# Action: search[vintage white women's t-shirt Halloween barbecue sauce needle sleeve easy delivery]
# Observation: Invalid action!
#
# Action: search[vintage white women's t-shirt Halloween barbecue sauce needle sleeve easy delivery]
# Observation: Invalid action!
#
# Action: search[vintage white women's t-shirt Halloween barbecue sauce needle sleeve easy delivery under 50 dollars]
# Observation: Invalid action!
#
# 105 0.1 0.0 0.0
# -------------
# -----------------
# 105
# Action: reset
# Observation:
# WebShop
# Instruction:
# i'm looking for black colored high quality hair removal cream it easy to use, and price lower than 30.00 dollars
# [Search]
#
# Action: search[black high quality hair removal cream easy to use]
# Observation:
# [Back to Search]
# Page 1 (Total results: 50)
# [Next >]
# [B08NB29KXH]
# Seki Japan Face Beauty Trimmer, Women's Facial Razor, Disposable Facial Hair Removal Groomer, with Safety Cover 3 Pieces
# $8.1
# [B07B41K2VV]
# Nair Hair Remover Sensitive Formula (Pack of 2)
# $16.53
# [B087TR48KK]
# Minkissy Eyebrow Hair Razors Eyebrow Trimmer Portable Facial Hair Remover Facail Hair Trimmer Hair Beauty Grooming Tool for Women and Men 4pcs
# $11.99
#
# Action: think[None of these options seem to match the criteria of black colored high quality hair removal cream that is easy to use and under 30.00 dollars. I can try searching again with different keywords.]
# Observation: OK.
#
# Action: search[black hair removal cream easy to use affordable]
# Observation: Invalid action!
#
# Action: search[black hair removal cream easy to use]
# Observation: Invalid action!
#
# Action: search[black hair removal cream easy to use]
# Observation: Invalid action!
#
# Action: search[black hair removal cream easy to use]
# Observation: Invalid action!
#
# Action: search[black hair removal cream easy to use]
# Observation: Invalid action!
#
# Action: search[black hair removal cream easy to use]
# Observation: Invalid action!
#
# Action: search[black hair removal cream easy to use]
# Observation: Invalid action!
#
# Action: search[black hair removal cream easy to use]
# Observation: Invalid action!
#
# Action: search[black hair removal cream easy to use]
# Observation: Invalid action!
#
# Action: search[black hair removal cream easy to use]
# Observation: Invalid action!
#
# Action: search[black hair removal cream easy to use]
# Observation: Invalid action!
#
# Action: search[black hair removal cream easy to use]
# Observation: Invalid action!
#
# 106 0.08333333333333333 0.0 0.0
# -------------
# -----------------
# 106
# Action: reset
# Observation:
# WebShop
# Instruction:
# i am looking for a white platform bed that is easy to assemble, and price lower than 300.00 dollars
# [Search]
#
# Action: search[white platform bed easy to assemble]
# Observation:
# [Back to Search]
# Page 1 (Total results: 50)
# [Next >]
# [B09QHT6WKQ]
# Twin Size Platform Bed for Kids Teens Adults, Metal Platform Bed Frame with Headboard and Footboard, 4 Wooden Feets, 2 Steel Legs, Metal Slats Support, No Box Spring Needed, Easy Assembly (Gray)
# $68.99
# [B09BNCFGLY]
# Wrington Storage Platform Bed, Frame Material: Solid Wood, Eco-Friendly Solid Hardwood with Non-Toxic Finish
# $1514.48
# [B0769HRGD2]
# Abbey Avenue Grace Upholstered Queen Platform Bed, Blue
# $376.46
#

# Observation: Invalid action!
#
# Action: search[s20 tv sound bar wireless bluetooth speaker affordable]
# Observation: Invalid action!
#
# Action: search[s20 tv sound bar wireless bluetooth speaker budget-friendly]
# Observation: Invalid action!
#
# Action: search[s20 tv sound bar wireless bluetooth speaker cheap]
# Observation: Invalid action!
#
# Action: search[s20 tv sound bar wireless bluetooth speaker budget]
# Observation: Invalid action!
#
# Action: search[s20 tv sound bar wireless bluetooth speaker best price]
# Observation: Invalid action!
#
# Action: search[s20 tv sound bar wireless bluetooth speaker deals]
# Observation: Invalid action!
#
# Action: search[s20 tv sound bar wireless bluetooth speaker discount]
# Observation: Invalid action!
#
# Action: search[s20 tv sound bar wireless bluetooth speaker sale]
# Observation: Invalid action!
#
# Action: search[s20 tv sound bar wireless bluetooth speaker affordable options]
# Observation: Invalid action!
#
# Action: search[s20 tv sound bar wireless bluetooth speaker under 80.00 dollars]
# Observation: Invalid action!
#
# Action: search[s20 tv sound bar wireless bluetooth speaker budget-friendly options]
# Observation: Invalid action!
#
# 112 0.125 0.0 0.0
# -------------
# -----------------
# 112
# Action: reset
# Observation:
# WebShop
# Instruction:
# i am looking for a headphones case that is apple compatible and is navy blue colored, and price lower than 40.00 dollars
# [Search]
#
# Action: search[apple compatible navy blue headphones case]
# Observation:
# [Back to Search]
# Page 1 (Total results: 50)
# [Next >]
# [B07VVVDRCX]
# iPad Case Fit 2018/2017 iPad 9.7 6th/5th Generation - 360 Degree Rotating iPad Air Case Cover with Auto Wake/Sleep Compatible with Apple iPad 9.7 Inch 2018/2017 (National Wind)
# $12.99
# [B098SV78BW]
# Square iPhone 11 Case,Tzomsze Cute Full Camera Lens Protection & Electroplate Reinforced Corners Shockproof Edge Bumper Case Compatible with iPhone 11 [6.1 inches] -Candy Pink
# $10.59
# [B09B7551X2]
# MNBVCXZ Watch Bands Compatible for Apple Watch Band 44mm 45mm 40mm 41mm with Protective Case for Men & Women, Sport Waterproof Strap for iWatch SE Series 7/6/5/4 (40mm 41mm,Midnight blue)
# $10.99
#
# Action: think[None of these options are headphones cases. I will try a different search term.]
# Observation: OK.
#
# Action: search[navy blue headphones case apple compatible]
# Observation: Invalid action!
#
# Action: search[navy blue headphones case for Apple devices]
# Observation: Invalid action!
#
# Action: search[navy blue headphones case Apple compatible]
# Observation: Invalid action!
#
# Action: search[navy blue headphones case Apple compatible]
# Observation: Invalid action!
#
# Action: search[navy blue headphones case Apple compatible]
# Observation: Invalid action!
#
# Action: search[navy blue headphones case Apple compatible]
# Observation: Invalid action!
#
# Action: search[navy blue headphones case Apple compatible]
# Observation: Invalid action!
#
# Action: search[navy blue headphones case Apple compatible]
# Observation: Invalid action!
#
# Action: search[navy blue headphones case Apple compatible]
# Observation: Invalid action!
#
# Action: search[navy blue headphones case Apple compatible]
# Observation: Invalid action!
#
# Action: search[navy blue headphones case Apple compatible]
# Observation: Invalid action!
#
# Action: search[navy blue headphones case Apple compatible]
# Observation: Invalid action!
#
# 113 0.11538461538461539 0.0 0.0
# -------------
# -----------------
# 113
# Action: reset
# Observation:
# WebShop
# Instruction:
# i need a pair of low rise yellow briefs in a large, and price lower than 40.00 dollars
# [Search]
#
# Action: search[low rise yellow briefs large]
# Observation:
# [Back to Search]
# Page 1 (Total results: 50)
# [Next >]
# [B09QW2HQRK]
# CandyMan Lace Pajama and Lounge Pants for Men
# $31.0 to $69.0
# [B09QCVCYVY]
# Burband Womens High Waist Bike Shorts Tummy Control Workout Yoga Pants Running Exercise Running Shorts with Side Pockets
# $6.82
# [B098B8KGMB]
# Sheer Lace G-String For Men Floral Briefs Sexy T-Back Underwears See Through G-Strings Jockstrap Bikini Briefs
# $2.99
#
# Action: think[None of the results match the criteria for low rise yellow briefs in a large size under 40 dollars. I will try a different search term.]
# Observation: OK.
#
# Action: search[low rise yellow briefs large under 40 dollars]
# Observation: Invalid action!
#
# Action: search[low rise yellow briefs large]
# Observation: Invalid action!
#
# Action: search[low rise yellow briefs large size under 40 dollars]
# Observation: Invalid action!
#
# Action: search[low rise yellow briefs large size]
# Observation: Invalid action!
#
# Action: search[low rise yellow briefs large size men under 40 dollars]
# Observation: Invalid action!
#
# Action: search[low rise yellow briefs large men]
# Observation: Invalid action!
#
# Action: search[low rise yellow briefs large men under 40 dollars]
# Observation: Invalid action!
#
# Action: search[low rise yellow briefs large men affordable]
# Observation: Invalid action!
#
# Action: search[low rise yellow briefs large men affordable]
# Observation: Invalid action!
#
# Action: search[low rise yellow briefs large men affordable]
# Observation: Invalid action!
#
# Action: search[low rise yellow briefs large men affordable]
# Observation: Invalid action!
#
# Action: search[low rise yellow briefs large men affordable]
# Observation: Invalid action!
#
# 114 0.10714285714285714 0.0 0.0
# -------------
# -----------------
# 114
# Action: reset
# Observation:
# WebShop
# Instruction:
# i want a easy install roller sades window tretment  size w45*h56 in color pastel blue, and price lower than 100.00 dollars
# [Search]
#
# Action: search[easy install roller shades window treatment w45*h56 pastel blue]
# Observation:
# [Back to Search]
# Page 1 (Total results: 50)
# [Next >]
# [B096RV56XP]
# PONY DANCE Kitchen Curtain for Windows - Semi-Sheer Decorative Roman Shade for Bedroom Tie Up Blinds Short Window Covering, 42" Wide by 45" Long, Dark Blue, Set of 1
# $16.95
# [B09LCM3NKN]
# Sheer Window Curtain Panels Cute Snowman Red Scarf Winter Snowflake,Semi Sheer Window Covering Privacy Drapes 2 Panel Sets Farm Vintage Board Green Grid Window Treatment for Kitchen/Living Room
# $44.05
# [B09QMGM5S3]
# IETONE 3 Pcs Portable Cylinder Face Oil-Absorbing Volcanic Roller, Reusable Volcanic Stone Facial Oil Remover Tools, Women Face Care Makeup Styling Keeper, Skincare Massage T-zone Oil Control Tools
# $10.99
#
# Action: think[There are no results matching the criteria for easy install roller shades window treatment size w45*h56 in pastel blue. I can try adjusting the search criteria or checking a different color.]
# Observation: OK.
#
# Action: search[easy install roller shades window treatment w45*h56 blue]
# Observation: Invalid action!
#
# Action: search[easy install roller shades window treatment w45*h56 light blue]
# Observation: Invalid action!
#
# Action: search[easy install roller shades window treatment w45*h56 baby blue]
# Observation: Invalid action!
#
# Action: search[easy install roller shades window treatment w45*h56 sky blue]
# Observation: Invalid action!
#
# Action: search[easy install roller shades window treatment w45*h56 blue]
# Observation: Invalid action!
#
# Action: search[easy install roller shades window treatment w45*h56 in blue]
# Observation: Invalid action!
#
# Action: search[easy install roller shades window treatment w45*h56 in blue color]
# Observation: Invalid action!
#
# Action: search[easy install roller shades window treatment w45*h56 in light blue]
# Observation: Invalid action!
#
# Action: search[easy install roller shades window treatment w45*h56 in blue color]
# Observation: Invalid action!
#
# Action: search[easy install roller shades window treatment w45*h56 in light blue color]
# Observation: Invalid action!
#
# Action: search[easy install roller shades window treatment w45*h56 in pastel color]
# Observation: Invalid action!
#
# Action: search[easy install roller shades window treatment w45*h56 in light blue color]
# Observation: Invalid action!
#
# 115 0.1 0.0 0.0
# -------------
# -----------------
# 115
# Action: reset
# Observation:
# WebShop
# Instruction:
# i'd like to find a large pink tankini swimsuit that's loose-fitting, and price lower than 50.00 dollars
# [Search]
#
# Action: search[large pink tankini swimsuit loose fitting]
# Observation:
# [Back to Search]
# Page 1 (Total results: 50)
# [Next >]
# [B09PL5W9PD]
# Women's One Piece Swimsuit Halter Plunge Neck Tummy Control Bathing Suits Push Up Tankini Sets Plus Size Beachwear
# $7.8
# [B09Q37JQZ6]
# Women's Sexy Swimsuit One Piece High Neck Halter Bikini Floral Stiching See Through Monokini Tummy Control Beachwear
# $10.99 to $18.99
# [B09S6LZYHQ]
# One Piece Swimsuit for Women Halter Cut Out Bathing Suit Sexy Criss Cross Swimwear Backless Tie Dye Monokini Beachwear
# $14.99
#
# Action: think[None of these options seem to match the criteria of a large pink tankini swimsuit that's loose-fitting. I can try a different search term or check another page.]
# Observation: OK.
#
# Action: search[loose fitting pink tankini swimsuit]
# Observation: Invalid action!
#
# Action: click[Next >]
# Observation: Invalid action!
#
# Action: click[Back to Search]
# Observation: Invalid action!
#
# Action: search[pink tankini swimsuit loose fitting]
# Observation: Invalid action!
#
# Action: search[loose fitting pink tankini swimsuit]
# Observation: Invalid action!
#
# Action: search[loose fitting pink tankini swimsuit]
# Observation: Invalid action!
#
# Action: search[pink tankini swimsuit loose fit]
# Observation: Invalid action!
#
# Action: search[pink tankini swimsuit loose fit]
# Observation: Invalid action!
#
# Action: search[pink tankini swimsuit loose fit]
# Observation: Invalid action!
#
# Action: search[pink tankini swimsuit loose fit]
# Observation: Invalid action!
#
# Action: search[pink tankini swimsuit loose fit]
# Observation: Invalid action!
#
# Action: search[loose fitting pink tankini swimsuit]
# Observation: Invalid action!
#
# 116 0.09375 0.0 0.0
# -------------
# -----------------
# 116
# Action: reset
# Observation:
# WebShop
# Instruction:
# i'm looking for a mini pc intel core desktop computer which supports with windows 11, and price lower than 750.00 dollars
# [Search]
#
# Action: search[mini pc intel core desktop computer windows 11]
# Observation:
# [Back to Search]
# Page 1 (Total results: 50)
# [Next >]
# [B06Y44FL9J]
# LINDY 36920 0.5m DisplayPort to HDMI 10.2G Cable, Black
# $17.31
# [B07PXMFDQ3]
# Dell Dual VESA Mount Stand with adaptor box for Micro Chassis - Customer Install - stand for monitor / mini PC - mounting interface: VESA
# $45.5
# [B09PTQFBNT]
# Mulyyds Computer Desk with Drawers and Open Shelves, Modern Writing Desk Student Study Table Gaming Workstations PC Laptop Corner Desk for Small Spaces Home Office Dormitory (White, 43x19x27in)
# $159.99
#
# Action: scroll[Looking for mini pc intel core desktop computer with windows 11 support]
# Observation: Invalid action!
#
# Action: scroll[mini pc intel core desktop computer windows 11]
# Observation: Invalid action!
#
# Action: click[Next >]
# Observation: Invalid action!
#
# Action: think[None of the results seem to match what I'm looking for. I may need to refine my search criteria or try a different search term.]
# Observation: OK.
#
# Action: back to search[mini pc intel core desktop computer windows 11]
# Observation: Invalid action!
#
# Action: search[mini pc intel core desktop computer windows 11 support]
# Observation: Invalid action!
#
# Action: search[mini pc intel core desktop computer windows 11 support]
# Observation: Invalid action!
#
# Action: search[mini pc intel core desktop computer windows 11 support]
# Observation: Invalid action!
#
# Action: search[mini pc intel core desktop computer windows 11 support under 750 dollars]
# Observation: Invalid action!
#
# Action: search[mini pc intel core desktop computer windows 11 under 750 dollars]
# Observation: Invalid action!
#
# Action: search[mini pc intel core desktop computer windows 11 under 750 dollars]
# Observation: Invalid action!
#
# Action: search[mini pc intel core desktop computer windows 11 under 750 dollars]
# Observation: Invalid action!
#
# Action: search[mini pc intel core desktop computer windows 11 under 750 dollars]
# Observation: Invalid action!
#
# 117 0.08823529411764706 0.0 0.0
# -------------
# -----------------
# 117
# Action: reset
# Observation:
# WebShop
# Instruction:
# i'm looking for headphones are color it was wireless charging it was outside of noise cancellation, and price lower than 210.00 dollars
# [Search]
#
# Action: search[color wireless charging headphones noise cancellation]
# Observation:
# [Back to Search]
# Page 1 (Total results: 50)
# [Next >]
# [B092W6WNH4]
# GAOMU IPX6 Waterproof Bluetooth Earbuds, True Wireless Earbuds, 20H Cyclic Playtime Headphones with Charging Case and mic for Android, in-Ear Stereo Earphones Headset for Sport Black
# $11.99
# [B09L86RDXS]
# Comfortable Bluetooth Headset, UX-M97 Wireless Headset with Microphone, Wireless Cell Phone Headset with Noise Isolation Mic Charging Base Mute Function for Xiaomi Poco F3 GT with Charging Dock
# $41.95
# [B095C2ZMTX]
# Mingbao Sound Quality Hi-Fi Stereo Speaker Wireless Bluetooth Soundbar Home Theater TV Strong Bass Sound Bar + Remote Control
# $100.0
#
# Action: think[None of these options match the criteria of color, wireless charging, and noise cancellation. I can try a different search term.]
# Observation: OK.
#
# Action: search[color wireless charging noise cancellation headphones]
# Observation: Invalid action!
#
# Action: search[color wireless charging noise cancellation headphones]
# Observation: Invalid action!
#
# Action: search[color wireless charging noise cancellation headphones]
# Observation: Invalid action!
#
# Action: search[color wireless charging noise cancellation headphones]
# Observation: Invalid action!
#
# Action: search[color wireless charging noise cancellation headphones]
# Observation: Invalid action!
#
# Action: search[color wireless charging noise cancellation headphones]
# Observation: Invalid action!
#
# Action: search[color wireless charging noise cancellation headphones]
# Observation: Invalid action!
#
# Action: search[color wireless charging noise cancellation headphones]
# Observation: Invalid action!
#
# Action: search[color wireless charging noise cancellation headphones]
# Observation: Invalid action!
#
# Action: search[color wireless charging noise cancellation headphones]
# Observation: Invalid action!
#
# Action: search[color wireless charging noise cancellation headphones]
# Observation: Invalid action!
#
# Action: search[color wireless charging noise cancellation headphones]
# Observation: Invalid action!
#
# 118 0.08333333333333333 0.0 0.0
# -------------
# -----------------
# 118
# Action: reset
# Observation:
# WebShop
# Instruction:
# i need a hair elastic for my hair extensions, and price lower than 60.00 dollars
# [Search]
#
# Action: search[hair elastic for hair extensions]
# Observation:
# [Back to Search]
# Page 1 (Total results: 50)
# [Next >]
# [B09G2F3HQ2]
# Lurrose 6pcs Girls Hair Bow Ribbon Barrettes Hair Bow Ribbon Clip Wig Hair Bow Clips with Alligator Clip and Hair Extensions Hair Accessory for Toddler Girls Children
# $11.99
# [B09MM9NCQQ]
# Simayixx Christmas Gift Wigs Hair Extensions 24 Inches Synthetic Long Natural Black Thick Clip Straight Hair Stylish Fasionable Fabulous Hair Piece 6 Pieces Popular Hairstyle(E)
# $7.83
# [B08ZKDQPZ3]
# Hair Tinsel Kit Strands With Tool 47 Inch 12 Colors 2100 Strands Fairy Hair Tinsel Kit Hair Extensions Sparkling Glitter Shiny Silk Tinsel (12 colors)
# $13.96
#
# Action: think[Lurrose 6pcs Girls Hair Bow Ribbon Barrettes Hair Bow Ribbon Clip Wig Hair Bow Clips with Alligator Clip and Hair Extensions Hair Accessory for Toddler Girls Children is a hair elastic for hair extensions less than 60 dollars. I can check B09G2F3HQ2 first.]
# Observation: OK.
#
# Action: click[B09G2F3HQ2]
# Observation:
# [Back to Search]
# [< Prev]
# Lurrose 6pcs Girls Hair Bow Ribbon Barrettes Hair Bow Ribbon Clip Wig Hair Bow Clips with Alligator Clip and Hair Extensions Hair Accessory for Toddler Girls Children
# Price: $11.99
# Rating: N.A.
# [Description]
# [Features]
# [Reviews]
# [Attributes]
# [Buy Now]
#
# Action: think

# Observation:
# [Back to Search]
# Page 1 (Total results: 50)
# [Next >]
# [B003HBR86S]
# Sea Gull Lighting 85200-12 Wynfield One-Light Outdoor Wall Lantern with Clear Beveled Glass Panels, Black Finish
# $61.17
# [B07TN3Y9H1]
# Maxim 32478SWSBRBP Finn Mid-Century Modern Satin White Glass Ball Bath Vanity Wall Mount, 5-Light 200 Total Watts, 7"H x 44"W, Satin Brass/Brushed Platinum
# $219.99
# [B01NCQLFPH]
# Designers Impressions Juno Oil Rubbed Bronze 2 Light Wall Sconce/Bathroom Fixture with Clear and Frosted Glass: 73470
# $55.95
#
# Action: think[None of the options are satin brass and frosted hallway light fixtures under 70 dollars. I will try a different search term or check other pages for more options.]
# Observation: OK.
#
# Action: search[satin brass frosted hallway light fixtures under 70 dollars]
# Observation: Invalid action!
#
# Action: search[satin brass frosted hallway light fixtures affordable]
# Observation: Invalid action!
#
# Action: search[satin brass frosted hallway light fixtures budget-friendly]
# Observation: Invalid action!
#
# Action: search[satin brass frosted hallway light fixtures inexpensive]
# Observation: Invalid action!
#
# Action: search[satin brass frosted hallway light fixtures cheap]
# Observation: Invalid action!
#
# Action: search[satin brass frosted hallway light fixtures under 70 dollars]
# Observation: Invalid action!
#
# Action: search[satin brass frosted hallway light fixtures budget]
# Observation: Invalid action!
#
# 121 0.14285714285714285 0.047619047619047616 0.0
# -------------
# -----------------
# 121
# Action: reset
# Observation:
# WebShop
# Instruction:
# i need an oval soft rug that is easy to clean. also, it should be in eggplant purple color, and price lower than 270.00 dollars
# [Search]
#
# Action: search[oval soft rug easy to clean eggplant purple]
# Observation:
# [Back to Search]
# Page 1 (Total results: 50)
# [Next >]
# [B07FKGQKZ1]
# Home Dynamix Lyndhurst Rotana Modern Area Rug, Contemporary Blue/Gray/Ivory 5'2"x7'4"
# $44.99 to $33.98
# [B09CQ45ZRB]
# Merry Christmas Kitchen Mat 2 PCS Cushioned Anti Fatigue Kitchen Runner Rugs Truck with Xmas Tree Red and Black Buffalo Plaid Comfort Standing Desk Mat for Office Floor Mat 19.7"x31.5"+19.7"x47.2"
# $15.9
# [B07Q87P8DQ]
# Permo Vintage Rustic Industrial 3-Lights Kitchen Island Chandelier Triple 3 Heads Pendant Hanging Ceiling Lighting Fixture with Oval Cone Clear Glass Shade (Antique)
# $94.99
#
# Action: think[None of these options match the criteria of an oval soft rug that is easy to clean in eggplant purple color and under 270.00 dollars. I will try a different search.]
# Observation: OK.
#
# Action: search[oval soft rug easy to clean eggplant purple under 270.00 dollars]
# Observation: Invalid action!
#
# Action: search[oval soft rug easy to clean eggplant purple]
# Observation: Invalid action!
#
# Action: search[oval soft rug eggplant purple under 270.00 dollars]
# Observation: Invalid action!
#
# Action: search[oval soft rug eggplant purple]
# Observation: Invalid action!
#
# Action: search[oval soft rug eggplant purple]
# Observation: Invalid action!
#
# Action: search[oval soft rug eggplant purple]
# Observation: Invalid action!
#
# Action: search[oval soft rug eggplant purple under 270.00 dollars]
# Observation: Invalid action!
#
# Action: search[oval soft rug eggplant purple under 270.00 dollars]
# Observation: Invalid action!
#
# Action: search[oval soft rug eggplant purple under 270.00 dollars]
# Observation: Invalid action!
#
# Action: search[oval soft rug eggplant purple under 270.00 dollars]
# Observation: Invalid action!
#
# Action: search[oval soft rug eggplant purple under 270.00 dollars]
# Observation: Invalid action!
#
# Action: search[oval soft rug eggplant purple under 270.00 dollars]
# Observation: Invalid action!
#
# 122 0.13636363636363635 0.045454545454545456 0.0
# -------------
# -----------------
# 122
# Action: reset
# Observation:
# WebShop
# Instruction:
# i need a gold plated hdmi adapter that is capable of 4k, and price lower than 40.00 dollars
# [Search]
#
# Action: search[gold plated hdmi adapter 4k]
# Observation:
# [Back to Search]
# Page 1 (Total results: 50)
# [Next >]
# [B08QSNM69H]
# 4K HDMI Cables, Short Cord, 1ft [3 Pack] Braided Cord & Gold Connectors, 1ft High-Speed HDMI 2.0 with Ethernet, for Playstation PS5, PS4, PS3, Xbox, Roku, Apple TV, HDTV, Blu-ray, Laptop, PC, Monitor
# $15.49
# [B01MQH5VGR]
# ...
# Observation: Invalid action!
#
# Action: search[long lasting press on nails 34 piece set]
# Observation: Invalid action!
#
# 147 0.14007092198581558 0.02127659574468085 0.0
# -------------
# -----------------
# 147
# Action: reset
# Observation:
# WebShop
# Instruction:
# i'm looking for 8.12 fluid ounces of sulfate-free shampoo that helps prevent hair loss, and price lower than 50.00 dollars
# [Search]
#
# Action: search[8.12 fluid ounces sulfate-free shampoo hair loss]
# Observation:
# [Back to Search]
# Page 1 (Total results: 50)
# [Next >]
# [B07B6DVG41]
# 100% PURE Glossy Locks: Repair Shampoo (13.5 Fl Oz), Sulfate Free Shampoo, Restores Damaged Hair, Moisturizing, Improves Hair Growth, Made with Biotin, Coconut Oil
# $34.0
# [B09SHRV5JW]
# Herbal Hair Regrowth Spray, Hair-growth Essence Spray, Herbal Hair Growth Essence Spray, Hair Growth Treatement Germinal Oil, Hair Growth Maximizer Spray for Prevent Postpartum Hair Loss Men Women (10ml 4PC)
# $16.99
# [B005P0T90C]
# Naturtint Permanent Hair Color 6G Dark Golden Blonde (Pack of 1), Ammonia Free, Vegan, Cruelty Free, up to 100% Gray Coverage, Long Lasting Results
# $13.6
#
# Action: think[B07B6DVG41 is sulfate-free shampoo for hair loss less than 50 dollars. I can check B07B6DVG41 first.]
# Observation: OK.
#
# Action: click[B07B6DVG41]
# Observation:
# [Back to Search]
# [< Prev]
# 100% PURE Glossy Locks: Repair Shampoo (13.5 Fl Oz), Sulfate Free Shampoo, Restores Damaged Hair, Moisturizing, Improves Hair Growth, Made with Biotin, Coconut Oil
# Price: $34.0
# Rating: N.A.
# [Description]
# [Features]
# [Reviews]
# [Attributes]
# [Buy Now]
#
# Action: think[For 8.12 fluid ounces of sulfate-free shampoo that helps prevent hair loss, the item '100% PURE Glossy Locks: Repair Shampoo' seems to fit the criteria and is priced at $34.0.]
# Observation: OK.
#
# Action: click[Buy Now]
# Observation: Your score (min 0.0, max 1.0): 0.75
#
# 148 0.15277777777777776 0.020833333333333332 0.0
# -------------
# -----------------
# 148
# Action: reset
# Observation:
# WebShop
# Instruction:
# i am looking for a square area rug that is grey and ivory and measures 2 feet by 2 inch by 17 feet, and price lower than 140.00 dollars
# [Search]
#
# Action: search[square area rug grey ivory 2 feet by 2 inch by 17 feet]
# Observation:
# [Back to Search]
# Page 1 (Total results: 50)
# [Next >]
# [B07FKGQKZ1]
# Home Dynamix Lyndhurst Rotana Modern Area Rug, Contemporary Blue/Gray/Ivory 5'2"x7'4"
# $44.99 to $33.98
# [B09CQ45ZRB]
# Merry Christmas Kitchen Mat 2 PCS Cushioned Anti Fatigue Kitchen Runner Rugs Truck with Xmas Tree Red and Black Buffalo Plaid Comfort Standing Desk Mat for Office Floor Mat 19.7"x31.5"+19.7"x47.2"
# $15.9
# [B08T9KJJPZ]
# Avon Anew Dark Circle Corrector Dual Eye System 2 Phase Care Against Dark Circles 20ml - 0.68 fl.oz
# $8.5
#
# Action: think[None of these options match the criteria of a square area rug that is grey and ivory and measures 2 feet by 2 inch by 17 feet. I will try a different search.]
# Observation: OK.
#
# Action: search[square area rug grey ivory 2'2" x 17' under $140]
# Observation: Invalid action!
#
# Action: search[square area rug grey ivory 2'2" x 17' under $140]
# Observation: Invalid action!
#
# Action: search[square area rug grey ivory 2'2" x 17' under $140]
# Observation: Invalid action!
#
# Action: search[square area rug grey ivory 2'2" x 17' under $140]
# Observation: Invalid action!
#
# Action: search[square area rug grey ivory 2'2" x 17' under $140]
# Observation: Invalid action!
#
# Action: search[square area rug grey ivory 2'2" x 17' under $140]
# Observation: Invalid action!
#
# Action: search[square area rug grey ivory 2'2" x 17' under $140]
# Observation: Invalid action!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 3
#       1 if not os.path.exists(expt_file_path):
#       2     os.makedirs(os.path.dirname(expt_file_path), exist_ok=True)
# ----> 3 res1 = run_episodes(prompt1, 500, expt_file_path)
#
# Cell In[13], line 39, in run_episodes(prompt, n, expt_file_path)
#      37 print(i)
#      38 try:
# ---> 39   r = webshop_run(f'fixed_{i}', prompt, to_print=True)
#      40 except AssertionError:
#      41   r = 0
#
# Cell In[13], line 28, in webshop_run(idx, prompt, to_print)
#      25   if res[2]:
#      26     return res[1]
# ---> 28   action = llm.llm(init_prompt + prompt[-(6400-len(init_prompt)):], stop=['\n']).lstrip(' ')
#      30 return 0
#
# Cell In[2], line 27, in LLM.llm(self, prompt, stop)
#      25 def llm(self, prompt, stop=["\n"]):
#      26     try :
# ---> 27         res = self._llm(prompt, stop)
#      28         return res
#      29     except Exception as e:
#
# Cell In[2], line 40, in LLM._llm(self, prompt, stop)
#      38 if LLM_MODEL in ["gpt-3.5-turbo", "gpt-4o-mini", "gpt-4o"]:
#      39     message = [{"role": "user", "content": prompt}]
# ---> 40     response = self.client.chat.completions.create(
#      41         model= LLM_MODEL,
#      42         messages= message,
#      43         temperature=0.0,
#      44         max_tokens=100,
#      45         top_p=1.0,
#      46         frequency_penalty=0.0,
#      47         presence_penalty=0.0,
#      48         stop=stop,
#      49     )
#      50     answer = response.choices[0].message.content
#      52 elif LLM_MODEL == "gpt-3.5-turbo-instruct":
#
# File /usr/local/lib/python3.9/dist-packages/openai/_utils/_utils.py:275, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     273             msg = f"Missing required argument: {quote(missing[0])}"
#     274     raise TypeError(msg)
# --> 275 return func(*args, **kwargs)
#
# File /usr/local/lib/python3.9/dist-packages/openai/resources/chat/completions.py:581, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     550 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     551 def create(
#     552     self,
#    (...)
#     579     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     580 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 581     return self._post(
#     582         "/chat/completions",
#     583         body=maybe_transform(
#     584             {
#     585                 "messages": messages,
#     586                 "model": model,
#     587                 "frequency_penalty": frequency_penalty,
#     588                 "function_call": function_call,
#     589                 "functions": functions,
#     590                 "logit_bias": logit_bias,
#     591                 "logprobs": logprobs,
#     592                 "max_tokens": max_tokens,
#     593                 "n": n,
#     594                 "presence_penalty": presence_penalty,
#     595                 "response_format": response_format,
#     596                 "seed": seed,
#     597                 "stop": stop,
#     598                 "stream": stream,
#     599                 "temperature": temperature,
#     600                 "tool_choice": tool_choice,
#     601                 "tools": tools,
#     602                 "top_logprobs": top_logprobs,
#     603                 "top_p": top_p,
#     604                 "user": user,
#     605             },
#     606             completion_create_params.CompletionCreateParams,
#     607         ),
#     608         options=make_request_options(
#     609             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     610         ),
#     611         cast_to=ChatCompletion,
#     612         stream=stream or False,
#     613         stream_cls=Stream[ChatCompletionChunk],
#     614     )
#
# File /usr/local/lib/python3.9/dist-packages/openai/_base_client.py:1233, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1219 def post(
#    1220     self,
#    1221     path: str,
#    (...)
#    1228     stream_cls: type[_StreamT] | None = None,
#    1229 ) -> ResponseT | _StreamT:
#    1230     opts = FinalRequestOptions.construct(
#    1231         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1232     )
# -> 1233     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /usr/local/lib/python3.9/dist-packages/openai/_base_client.py:922, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     913 def request(
#     914     self,
#     915     cast_to: Type[ResponseT],
#    (...)
#     920     stream_cls: type[_StreamT] | None = None,
#     921 ) -> ResponseT | _StreamT:
# --> 922     return self._request(
#     923         cast_to=cast_to,
#     924         options=options,
#     925         stream=stream,
#     926         stream_cls=stream_cls,
#     927         remaining_retries=remaining_retries,
#     928     )
#
# File /usr/local/lib/python3.9/dist-packages/openai/_base_client.py:951, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     948     kwargs["auth"] = self.custom_auth
#     950 try:
# --> 951     response = self._client.send(
#     952         request,
#     953         stream=stream or self._should_stream_response_body(request=request),
#     954         **kwargs,
#     955     )
#     956 except httpx.TimeoutException as err:
#     957     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File /usr/local/lib/python3.9/dist-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     906 follow_redirects = (
#     907     self.follow_redirects
#     908     if isinstance(follow_redirects, UseClientDefault)
#     909     else follow_redirects
#     910 )
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File /usr/local/lib/python3.9/dist-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File /usr/local/lib/python3.9/dist-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File /usr/local/lib/python3.9/dist-packages/httpx/_client.py:1015, in Client._send_single_request(self, request)
#    1010     raise RuntimeError(
#    1011         "Attempted to send an async request with a sync Client instance."
#    1012     )
#    1014 with request_context(request=request):
# -> 1015     response = transport.handle_request(request)
#    1017 assert isinstance(response.stream, SyncByteStream)
#    1019 response.request = request
#
# File /usr/local/lib/python3.9/dist-packages/httpx/_transports/default.py:233, in HTTPTransport.handle_request(self, request)
#     220 req = httpcore.Request(
#     221     method=request.method,
#     222     url=httpcore.URL(
#    (...)
#     230     extensions=request.extensions,
#     231 )
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#     237 return Response(
#     238     status_code=resp.status,
#     239     headers=resp.headers,
#     240     stream=ResponseStream(resp.stream),
#     241     extensions=resp.extensions,
#     242 )
#
# File /usr/local/lib/python3.9/dist-packages/httpcore/_sync/connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, Iterable)
#
# File /usr/local/lib/python3.9/dist-packages/httpcore/_sync/connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     192 connection = pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File /usr/local/lib/python3.9/dist-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File /usr/local/lib/python3.9/dist-packages/httpcore/_sync/http11.py:143, in HTTP11Connection.handle_request(self, request)
#     141     with Trace("response_closed", logger, request) as trace:
#     142         self._response_closed()
# --> 143 raise exc
#
# File /usr/local/lib/python3.9/dist-packages/httpcore/_sync/http11.py:113, in HTTP11Connection.handle_request(self, request)
#     102     pass
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#     121 network_stream = self._network_stream
#
# File /usr/local/lib/python3.9/dist-packages/httpcore/_sync/http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     183 timeout = timeouts.get("read", None)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#     188         break
#
# File /usr/local/lib/python3.9/dist-packages/httpcore/_sync/http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File /usr/local/lib/python3.9/dist-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# File /usr/lib/python3.9/ssl.py:1226, in SSLSocket.recv(self, buflen, flags)
#    1222     if flags != 0:
#    1223         raise ValueError(
#    1224             "non-zero flags not allowed in calls to recv() on %s" %
#    1225             self.__class__)
# -> 1226     return self.read(buflen)
#    1227 else:
#    1228     return super().recv(buflen, flags)
#
# File /usr/lib/python3.9/ssl.py:1101, in SSLSocket.read(self, len, buffer)
#    1099         return self._sslobj.read(len, buffer)
#    1100     else:
# -> 1101         return self._sslobj.read(len)
#    1102 except SSLError as x:
#    1103     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
# fx = 50 
# webshop_run(f'fixed_{fx}', prompt1, to_print=True)
